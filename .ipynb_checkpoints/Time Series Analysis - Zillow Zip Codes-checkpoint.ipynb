# %% [markdown]
# # Time Series Modeling Project
# * Student name: Tara Mullin
# * Student pace: Part time
# * Scheduled project review date/time: 10/xx/19 xx:xxpm
# * Instructor name: Victor Geislinger
# * Blog post URL: TBD

# %% [markdown]
# ## Project Goal?
#
# To forcast real estate prices of various zipcodes using data from Zillow using time-series analysis.

# %% [markdown]
# What are the top 5 zip codes to invest in?
#
# Ideas:
# * least volitial?
# * gained most value?
# * more affordable now, but adjacent to valuable zip?
# * spread risk across 5 zip codes?

# %% [markdown]
# Should recommendations be focused on profit margins only? What about risk? What sort of time horizon to predict against? Recommendations will detail the rationale and will define "best".

# %% [markdown]
# # Preparing Data for Modeling & EDA

# %% [markdown]
# ## Step 1: Load the Data/Filtering for Chosen Zipcodes

# %%
import pandas as pd
zip_data = pd.read_csv("zillow_data.csv")
zip_data.head(15)
# Out:
#     RegionID  RegionName           City State              Metro  \
# 0      84654       60657        Chicago    IL            Chicago
# 1      90668       75070       McKinney    TX  Dallas-Fort Worth
# 2      91982       77494           Katy    TX            Houston
# 3      84616       60614        Chicago    IL            Chicago
# 4      93144       79936        El Paso    TX            El Paso
# 5      91733       77084        Houston    TX            Houston
# 6      61807       10467       New York    NY           New York
# 7      84640       60640        Chicago    IL            Chicago
# 8      91940       77449           Katy    TX            Houston
# 9      97564       94109  San Francisco    CA      San Francisco
# 10     62037       11226       New York    NY           New York
# 11     71831       32162   The Villages    FL       The Villages
# 12     62087       11375       New York    NY           New York
# 13     62045       11235       New York    NY           New York
# 14     74101       37013      Nashville    TN          Nashville
#
#        CountyName  SizeRank   1996-04   1996-05   1996-06   ...     2017-07  \
# 0            Cook         1  334200.0  335400.0  336500.0   ...     1005500
# 1          Collin         2  235700.0  236900.0  236700.0   ...      308000
# 2          Harris         3  210400.0  212200.0  212200.0   ...      321000
# 3            Cook         4  498100.0  500900.0  503100.0   ...     1289800
# 4         El Paso         5   77300.0   77300.0   77300.0   ...      119100
# 5          Harris         6   95000.0   95200.0   95400.0   ...      157900
# 6           Bronx         7  152900.0  152700.0  152600.0   ...      394400
# 7            Cook         8  216500.0  216700.0  216900.0   ...      798000
# 8          Harris         9   95400.0   95600.0   95800.0   ...      166800
# 9   San Francisco        10  766000.0  771100.0  776500.0   ...     3767700
# 10          Kings        11  162000.0  162300.0  162600.0   ...      860200
# 11         Sumter        12  101000.0  100700.0  100400.0   ...      249900
# 12         Queens        13  252400.0  251800.0  251400.0   ...     1022600
# 13          Kings        14  190500.0  191000.0  191500.0   ...      767300
# 14       Davidson        15  112400.0  112700.0  113000.0   ...      193000
#
#     2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0   1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1    310000   312500   314100   315000   316600   318100   319600   321100
# 2    320600   320200   320400   320800   321200   321200   323000   326900
# 3   1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4    119400   120000   120300   120300   120300   120300   120500   121000
# 5    158700   160200   161900   162800   162800   162800   162900   163500
# 6    400000   407300   411600   413200   414300   413900   411400   413200
# 7    787100   776100   774900   777900   777900   778500   780500   782800
# 8    167400   168400   169600   170900   172300   173300   174200   175400
# 9   3763900  3775000  3799700  3793900  3778700  3770800  3763100  3779800
# 10   851000   853900   870000   885100   887800   890500   901700   930700
# 11   250400   249900   248700   247500   247100   246800   247500   249800
# 12  1033700  1048600  1066400  1081200  1088800  1092700  1089500  1084000
# 13   777300   788800   793900   796000   799700   806600   810600   813400
# 14   194900   196600   198800   201300   203800   205900   207600   210000
#
#     2018-04
# 0   1030600
# 1    321800
# 2    329900
# 3   1307000
# 4    121500
# 5    164300
# 6    417900
# 7    782800
# 8    176200
# 9   3813500
# 10   963200
# 11   251800
# 12  1084600
# 13   816200
# 14   211900
#
# [15 rows x 272 columns]

# %%
dc_zips = zip_data.loc[zip_data['State'] == 'DC']
dc_zips.head()
# Out:
#      RegionID  RegionName        City State       Metro            CountyName  \
# 29      66126       20002  Washington    DC  Washington  District of Columbia
# 33      66133       20009  Washington    DC  Washington  District of Columbia
# 181     66135       20011  Washington    DC  Washington  District of Columbia
# 246     66142       20019  Washington    DC  Washington  District of Columbia
# 258     66125       20001  Washington    DC  Washington  District of Columbia
#
#      SizeRank   1996-04   1996-05   1996-06   ...     2017-07  2017-08  \
# 29         30   94300.0   94000.0   93700.0   ...      662800   668000
# 33         34  178800.0  179200.0  179600.0   ...     1020000  1027500
# 181       182  118900.0  118500.0  118200.0   ...      582200   586200
# 246       247   91300.0   91000.0   90600.0   ...      291100   296300
# 258       259   92000.0   92600.0   93200.0   ...      765000   768800
#
#      2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 29    672200   673100   674600   678200   680900   683000   687500   691300
# 33   1034300  1040500  1047400  1055400  1065900  1076400  1081000  1078200
# 181   591200   593200   591200   589500   590800   599100   611400   619100
# 246   302500   306700   308800   310800   313400   314100   311800   308600
# 258   771200   773300   777600   780500   781600   785500   791400   793300
#
# [5 rows x 272 columns]

# %%
dc_zips.describe()
# Out:
#            RegionID    RegionName     SizeRank        1996-04        1996-05  \
# count     18.000000     18.000000    18.000000      18.000000      18.000000
# mean   66137.444444  20014.500000  2675.000000  189216.666667  188611.111111
# std        8.204893      9.739247  2493.070915  113639.762356  112984.735507
# min    66125.000000  20001.000000    30.000000   85700.000000   85500.000000
# 25%    66132.250000  20008.250000   295.000000  106000.000000  105650.000000
# 50%    66137.000000  20013.500000  1887.500000  126500.000000  126250.000000
# 75%    66141.750000  20018.750000  5329.500000  260800.000000  258900.000000
# max    66155.000000  20037.000000  6888.000000  450100.000000  448200.000000
#
#              1996-06        1996-07        1996-08        1996-09  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   188011.111111  187438.888889  186900.000000  186494.444444
# std    112325.089591  111657.064995  111042.609734  110470.493650
# min     85400.000000   85200.000000   85000.000000   84800.000000
# 25%    105250.000000  104875.000000  104500.000000  104175.000000
# 50%    126000.000000  125800.000000  125750.000000  125900.000000
# 75%    256925.000000  254950.000000  252950.000000  251175.000000
# max    446300.000000  444500.000000  442900.000000  441600.000000
#
#              1996-10      ...            2017-07       2017-08       2017-09  \
# count      18.000000      ...       1.800000e+01  1.800000e+01  1.800000e+01
# mean   186222.222222      ...       7.796444e+05  7.829056e+05  7.852778e+05
# std    109997.794393      ...       3.443848e+05  3.440163e+05  3.421486e+05
# min     84600.000000      ...       2.881000e+05  2.934000e+05  2.978000e+05
# 25%    104025.000000      ...       5.462750e+05  5.479500e+05  5.492750e+05
# 50%    126250.000000      ...       7.489000e+05  7.552500e+05  7.610500e+05
# 75%    249475.000000      ...       9.769750e+05  9.817250e+05  9.836500e+05
# max    440700.000000      ...       1.501600e+06  1.508800e+06  1.509700e+06
#
#             2017-10       2017-11       2017-12       2018-01       2018-02  \
# count  1.800000e+01  1.800000e+01  1.800000e+01  1.800000e+01  1.800000e+01
# mean   7.862611e+05  7.881222e+05  7.904500e+05  7.936222e+05  7.988389e+05
# std    3.396671e+05  3.391489e+05  3.395134e+05  3.403082e+05  3.412926e+05
# min    3.015000e+05  3.037000e+05  3.040000e+05  3.046000e+05  3.068000e+05
# 25%    5.500000e+05  5.486750e+05  5.514000e+05  5.543500e+05  5.610000e+05
# 50%    7.648000e+05  7.684500e+05  7.711500e+05  7.725500e+05  7.766500e+05
# 75%    9.836250e+05  9.869000e+05  9.909750e+05  9.952000e+05  1.002325e+06
# max    1.506000e+06  1.509100e+06  1.514300e+06  1.519400e+06  1.527900e+06
#
#             2018-03       2018-04
# count  1.800000e+01  1.800000e+01
# mean   8.046000e+05  8.061667e+05
# std    3.427029e+05  3.431798e+05
# min    3.082000e+05  3.074000e+05
# 25%    5.682000e+05  5.703500e+05
# 50%    7.830500e+05  7.857500e+05
# 75%    1.011925e+06  1.015700e+06
# max    1.539600e+06  1.545900e+06
#
# [8 rows x 268 columns]

# %%
dc_zips.RegionName.unique()
# Out:
# array([20002, 20009, 20011, 20019, 20001, 20020, 20008, 20003, 20032,
#        20016, 20010, 20007, 20024, 20017, 20018, 20037, 20015, 20012])

# %% [markdown]
# ## Step 2: Data Preprocessing

# %% [markdown]
# ## Step 3: Reshape from Wide to Long Format

# %%
def melt_data(df):
    melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %%
df = dc_zips[dc_zips.RegionName == 20002]
df.head()
# Out:
#     RegionID  RegionName        City State       Metro            CountyName  \
# 29     66126       20002  Washington    DC  Washington  District of Columbia
#
#     SizeRank  1996-04  1996-05  1996-06   ...     2017-07  2017-08  2017-09  \
# 29        30  94300.0  94000.0  93700.0   ...      662800   668000   672200
#
#     2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 29   673100   674600   678200   680900   683000   687500   691300
#
# [1 rows x 272 columns]

# %%
melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')

# %%
melted.head()
# Out:
#    RegionID  RegionName        City State       Metro            CountyName  \
# 0     66126       20002  Washington    DC  Washington  District of Columbia
# 1     66126       20002  Washington    DC  Washington  District of Columbia
# 2     66126       20002  Washington    DC  Washington  District of Columbia
# 3     66126       20002  Washington    DC  Washington  District of Columbia
# 4     66126       20002  Washington    DC  Washington  District of Columbia
#
#    SizeRank     time    value
# 0        30  1996-04  94300.0
# 1        30  1996-05  94000.0
# 2        30  1996-06  93700.0
# 3        30  1996-07  93600.0
# 4        30  1996-08  93400.0

# %%
melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)

# %%
melted = melted.dropna(subset=['value'])

# %%
melted.head()
# Out:
#    RegionID  RegionName        City State       Metro            CountyName  \
# 0     66126       20002  Washington    DC  Washington  District of Columbia
# 1     66126       20002  Washington    DC  Washington  District of Columbia
# 2     66126       20002  Washington    DC  Washington  District of Columbia
# 3     66126       20002  Washington    DC  Washington  District of Columbia
# 4     66126       20002  Washington    DC  Washington  District of Columbia
#
#    SizeRank       time    value
# 0        30 1996-04-01  94300.0
# 1        30 1996-05-01  94000.0
# 2        30 1996-06-01  93700.0
# 3        30 1996-07-01  93600.0
# 4        30 1996-08-01  93400.0

# %%
zip_dict = {}
for z in dc_zips.RegionName.unique():
    temp_df = dc_zips[dc_zips.RegionName == z]
    zip_dict[z] = melt_data(temp_df)

# %%
zip_dict.items()
# Out:
# dict_items([(20002,                value
# time
# 1996-04-01   94300.0
# 1996-05-01   94000.0
# 1996-06-01   93700.0
# 1996-07-01   93600.0
# 1996-08-01   93400.0
# 1996-09-01   93400.0
# 1996-10-01   93400.0
# 1996-11-01   93600.0
# 1996-12-01   94000.0
# 1997-01-01   94500.0
# 1997-02-01   95000.0
# 1997-03-01   95500.0
# 1997-04-01   95900.0
# 1997-05-01   96300.0
# 1997-06-01   96600.0
# 1997-07-01   96800.0
# 1997-08-01   96900.0
# 1997-09-01   97000.0
# 1997-10-01   97100.0
# 1997-11-01   97400.0
# 1997-12-01   97800.0
# 1998-01-01   98500.0
# 1998-02-01   99300.0
# 1998-03-01  100200.0
# 1998-04-01  101300.0
# 1998-05-01  102600.0
# 1998-06-01  104100.0
# 1998-07-01  105700.0
# 1998-08-01  107300.0
# 1998-09-01  109000.0
# ...              ...
# 2015-11-01  586100.0
# 2015-12-01  587400.0
# 2016-01-01  587100.0
# 2016-02-01  587700.0
# 2016-03-01  590500.0
# 2016-04-01  595300.0
# 2016-05-01  600000.0
# 2016-06-01  604900.0
# 2016-07-01  608100.0
# 2016-08-01  608800.0
# 2016-09-01  609300.0
# 2016-10-01  613900.0
# 2016-11-01  621100.0
# 2016-12-01  629200.0
# 2017-01-01  637800.0
# 2017-02-01  645300.0
# 2017-03-01  648900.0
# 2017-04-01  650500.0
# 2017-05-01  654000.0
# 2017-06-01  658800.0
# 2017-07-01  662800.0
# 2017-08-01  668000.0
# 2017-09-01  672200.0
# 2017-10-01  673100.0
# 2017-11-01  674600.0
# 2017-12-01  678200.0
# 2018-01-01  680900.0
# 2018-02-01  683000.0
# 2018-03-01  687500.0
# 2018-04-01  691300.0
#
# [265 rows x 1 columns]), (20009,                 value
# time
# 1996-04-01   178800.0
# 1996-05-01   179200.0
# 1996-06-01   179600.0
# 1996-07-01   180000.0
# 1996-08-01   180300.0
# 1996-09-01   180700.0
# 1996-10-01   181200.0
# 1996-11-01   181800.0
# 1996-12-01   182600.0
# 1997-01-01   183700.0
# 1997-02-01   184800.0
# 1997-03-01   185600.0
# 1997-04-01   186600.0
# 1997-05-01   187500.0
# 1997-06-01   188500.0
# 1997-07-01   189400.0
# 1997-08-01   190400.0
# 1997-09-01   191400.0
# 1997-10-01   192500.0
# 1997-11-01   193700.0
# 1997-12-01   195200.0
# 1998-01-01   197000.0
# 1998-02-01   198600.0
# 1998-03-01   200100.0
# 1998-04-01   201700.0
# 2017-01-01  637800.0
# 2017-02-01  645300.0
# 2017-03-01  648900.0
# 2017-04-01  650500.0
# 2017-05-01  654000.0
# 2017-06-01  658800.0
# 2017-07-01  662800.0
# 2017-08-01  668000.0
# 2017-09-01  672200.0
# 2017-10-01  673100.0
# 2017-11-01  674600.0
# 2017-12-01  678200.0
# 2018-01-01  680900.0
# 2018-02-01  683000.0
# 2018-03-01  687500.0
# 2018-04-01  691300.0
#
# [265 rows x 1 columns]

# %% [markdown]
# Next Steps:
#
#     * group by ward?
#     * plot a zip code over time
#     * plot 2, 5, up to 12 together over time
#     * choose 5 to model to understand the projected outcome of these 5
#     * could model all zips, but not expected for the project

# %% [markdown]
# ## Step 4: EDA and Visualization

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# NOTE: if your visualizations are too cluttered to read, try calling 'plt.gcf().autofmt_xdate()'!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-60bfcf298475> in <module>()
#       3         'size'   : 22}
#       4
# ----> 5 matplotlib.rc('font', **font)
#       6
#       7 # NOTE: if your visualizations are too cluttered to read, try calling 'plt.gcf().autofmt_xdate()'!
#
# NameError: name 'matplotlib' is not defined

# %%
import matplotlib.pyplot as plt

zip_dict[20002].plot(figsize = (15,5), subplots=False, legend=True)
zip_dict[20009].plot(figsize = (15,5), subplots=False, legend=True)
plt.show()

# %%
plt.plot(zip_dict[20001], label='20001')
plt.plot(zip_dict[20002], label='20002')
plt.plot(zip_dict[20003], label='20003')
plt.plot(zip_dict[20007], label='20007')
plt.plot(zip_dict[20008], label='20008')
plt.plot(zip_dict[20009], label='20009')
plt.plot(zip_dict[20010], label='20010')
plt.plot(zip_dict[20011], label='20011')
plt.plot(zip_dict[20012], label='20012')
plt.plot(zip_dict[20015], label='20015')
plt.plot(zip_dict[20016], label='20016')
plt.plot(zip_dict[20017], label='20017')
plt.plot(zip_dict[20018], label='20018')
plt.plot(zip_dict[20019], label='20019')
plt.plot(zip_dict[20020], label='20020')
plt.plot(zip_dict[20024], label='20024')
plt.plot(zip_dict[20032], label='20032')
plt.plot(zip_dict[20037], label='20037')
plt.legend(loc='upper left')
plt.show()

# %%
#Zip codes in NW include 20001, 20004, 20005, 20036, 20009, 20007, 20010, 2008, and 20016.

plt.plot(zip_dict[20001], label='20001')
plt.plot(zip_dict[20007], label='20007')
plt.plot(zip_dict[20008], label='20008')
plt.plot(zip_dict[20009], label='20009')
plt.plot(zip_dict[20010], label='20010')
plt.plot(zip_dict[20016], label='20016')
plt.legend(loc='upper left')
plt.show()

# %%
zip_dict[20001].iloc[0,0]
# Out:
# 92000.0

# %%
zip_dict["20001_scaled"]=zip_dict[20001]-zip_dict[20001].iloc[0,0]

# %%
#scaled: (current - first) / first = % rtn

zip_dict["20001_scaled"]=(zip_dict[20001]-zip_dict[20001].iloc[0,0])/zip_dict[20001].iloc[0,0]
zip_dict["20002_scaled"]=(zip_dict[20002]-zip_dict[20002].iloc[0,0])/zip_dict[20002].iloc[0,0]
zip_dict["20003_scaled"]=(zip_dict[20003]-zip_dict[20003].iloc[0,0])/zip_dict[20003].iloc[0,0]
zip_dict["20007_scaled"]=(zip_dict[20007]-zip_dict[20007].iloc[0,0])/zip_dict[20007].iloc[0,0]
zip_dict["20008_scaled"]=(zip_dict[20008]-zip_dict[20008].iloc[0,0])/zip_dict[20008].iloc[0,0]
zip_dict["20009_scaled"]=(zip_dict[20009]-zip_dict[20009].iloc[0,0])/zip_dict[20009].iloc[0,0]
zip_dict["20010_scaled"]=(zip_dict[20010]-zip_dict[20010].iloc[0,0])/zip_dict[20010].iloc[0,0]
zip_dict["20011_scaled"]=(zip_dict[20011]-zip_dict[20011].iloc[0,0])/zip_dict[20011].iloc[0,0]
zip_dict["20012_scaled"]=(zip_dict[20012]-zip_dict[20012].iloc[0,0])/zip_dict[20012].iloc[0,0]
zip_dict["20015_scaled"]=(zip_dict[20015]-zip_dict[20015].iloc[0,0])/zip_dict[20015].iloc[0,0]
zip_dict["20016_scaled"]=(zip_dict[20016]-zip_dict[20016].iloc[0,0])/zip_dict[20016].iloc[0,0]
zip_dict["20017_scaled"]=(zip_dict[20017]-zip_dict[20017].iloc[0,0])/zip_dict[20017].iloc[0,0]
zip_dict["20018_scaled"]=(zip_dict[20018]-zip_dict[20018].iloc[0,0])/zip_dict[20018].iloc[0,0]
zip_dict["20019_scaled"]=(zip_dict[20019]-zip_dict[20019].iloc[0,0])/zip_dict[20019].iloc[0,0]
zip_dict["20020_scaled"]=(zip_dict[20020]-zip_dict[20020].iloc[0,0])/zip_dict[20020].iloc[0,0]
zip_dict["20024_scaled"]=(zip_dict[20024]-zip_dict[20024].iloc[0,0])/zip_dict[20024].iloc[0,0]
zip_dict["20032_scaled"]=(zip_dict[20032]-zip_dict[20032].iloc[0,0])/zip_dict[20032].iloc[0,0]
zip_dict["20037_scaled"]=(zip_dict[20037]-zip_dict[20037].iloc[0,0])/zip_dict[20037].iloc[0,0]

# %%
plt.plot(zip_dict["20001_scaled"], label='20001 scaled')
plt.plot(zip_dict["20002_scaled"], label='20002 scaled')
plt.plot(zip_dict["20003_scaled"], label='20003 scaled')
plt.plot(zip_dict["20007_scaled"], label='20007 scaled')
plt.plot(zip_dict["20008_scaled"], label='20008 scaled')
plt.plot(zip_dict["20009_scaled"], label='20009 scaled')
plt.plot(zip_dict["20010_scaled"], label='20010 scaled')
plt.plot(zip_dict["20011_scaled"], label='20011 scaled')
plt.plot(zip_dict["20012_scaled"], label='20012 scaled')
plt.plot(zip_dict["20015_scaled"], label='20015 scaled')
plt.plot(zip_dict["20016_scaled"], label='20016 scaled')
plt.plot(zip_dict["20017_scaled"], label='20017 scaled')
plt.plot(zip_dict["20018_scaled"], label='20018 scaled')
plt.plot(zip_dict["20019_scaled"], label='20019 scaled')
plt.plot(zip_dict["20020_scaled"], label='20020 scaled')
plt.plot(zip_dict["20024_scaled"], label='20024 scaled')
plt.plot(zip_dict["20037_scaled"], label='20037 scaled')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(zip_dict[20003], label='20003')
plt.plot(zip_dict[20007], label='20007')
plt.plot(zip_dict[20009], label='20009')
plt.plot(zip_dict[20018], label='20018')
plt.plot(zip_dict[20001], label='20001')
plt.legend(loc='upper left')
plt.show()

# %%
#Most linear time series forecasting methods assume normal distribution of observations. Check with .hist() or .plot(kind='kde')

# %%
zip20001 = zip_data.loc[zip_data['RegionName'] == 20001]
zip20001.head()
# Out:
#      RegionID  RegionName        City State       Metro            CountyName  \
# 258     66125       20001  Washington    DC  Washington  District of Columbia
#
#      SizeRank  1996-04  1996-05  1996-06   ...     2017-07  2017-08  2017-09  \
# 258       259  92000.0  92600.0  93200.0   ...      765000   768800   771200
#
#      2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 258   773300   777600   780500   781600   785500   791400   793300
#
# [1 rows x 272 columns]

# %%
melted20001 = melt_data(zip20001)
melted20001.head()
# Out:
#               value
# time
# 1996-04-01  92000.0
# 1996-05-01  92600.0
# 1996-06-01  93200.0
# 1996-07-01  93900.0
# 1996-08-01  94600.0

# %%
melted20001.isna().sum()
# Out:
# value    0
# dtype: int64

# %%
#melted20001 = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')

# %%
#melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)

# %%
#melted = melted.dropna(subset=['value'])

# %%
#melted.head()

# %% [markdown]
# # ARIMA Modeling

# %% [markdown]
# ## Parameter Selection for ARIMA Time Series Model

# %% [markdown]
# The first step towards fitting an ARIMA model is to find the values of `ARIMA(p,d,q)(P,D,Q)s` that produce the desired output. Selection of these parameters requires domain expertise and time.  We shall first generate small ranges of these parameters and use a "grid search" to iteratively explore different combinations of parameters. For each combination of parameters, we fit a new seasonal ARIMA model with the `SARIMAX()` function from the statsmodels module and assess its overall quality.
#
# `SARIMAX` detailed documentation can be viewed [here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
#
# Let's begin by generating example combination of parameters that we wish to use.
#
# 1. Define p,q and d parameters to take any value from 0/1 using `range()` function. (Note: We can try larger values which can make our model computationally expensive to run, you can try this as an additional experiment)
#
# 2. Generate combinations for `(p,d,q)` using `itertools.product`.
# 3. Similarly, generate seasonal combinations as `(p,d,q)s`. Use s = 12 (constant)
# 4. Print some example combinations for seasonal ARIMA

# %%
import itertools

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0,2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets (use 12 for frequency)
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]


    # Define the p, d and q parameters to take any value between 0 and 2, 0-4 would be highest to try
    #p = d = q = range(0,2)

    # Generate all different combinations of p, q and q triplets
    #pdq = list(itertools.product(p, d, q))

    # Generate all different combinations of seasonal p, q and q triplets (use 12 for frequency)
    #pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %% [markdown]
# ## AIC (Akaike information Criterion) as Regularization Measure

# %% [markdown]
# For evaluating the model, we shall use the AIC (Akaike Information Criterion) value, which is provided by ARIMA models fitted using `statsmodels` library. The Akaike information criterion (AIC) is an estimator of the relative quality of statistical models for a given set of data. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models. Thus, AIC provides a means for model selection.
#
# A model that fits the data very well while using lots of features will be assigned a larger AIC score than a model that uses fewer features to achieve the same goodness-of-fit. Therefore, we are interested in finding the model that yields the lowest AIC value. To achieve this, perform following tasks:
#
# 1. Initialize an empty list to store results
# 2. iterate through all the paramaters in pdq with parameters in seasonal pdq (nested loop ) to create a grid
# 3. Run `SARIMAX` from statsmodels for each iteration. Details can be found [HERE](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html). Set `enforce_stationarity` and `enforce_invertibility` to False.
# 4. Get the results in each iteration with `model.fit()` and store the AIC values.
# 5. Find the lowest AIC and select parameters for further analysis.
#
# NOTE:
# * Integrate exception handling with `continue`.
# * An overview of Akaike Information Criterion can be viewed [HERE](http://www.statisticshowto.com/akaikes-information-criterion/)

# %%
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(zip_dict[20001],
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7607.3094680875965
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7109.73777056729
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6153.409075272848
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5873.529158829102
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =6040.0946863308545
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5966.084009863183
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5655.5583561289695
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =5635.086083943744
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7387.051587441354
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7362.489921991718
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =5954.440077969369
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =8161.497568330564
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7044.541238177362
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =6990.752551082477
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5672.386217201743
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7423.211916866556
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5156.3268564888285
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4883.152775759111
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4864.5795254941895
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4617.951332367549
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4834.949666968064
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4813.248466085148
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4622.047079089364
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4606.417305547146
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4812.156746545834
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4546.146955910248
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4668.914426852758
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4341.343249667372
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4617.422036681702
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4534.484155039174
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4434.956582744468
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4377.037381464817
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5049.472038975923
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4909.093870003696
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4884.835366663662
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4675.471997860842
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4797.6759997248555
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4798.987498044611
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4625.889356555569
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4627.72657364459
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4807.687018009315
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4586.492976628051
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4854.154053847542
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4378.186661487233
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4612.7619345201565
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4588.483088985295
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4440.405152894004
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4665.544993010512
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4499.797818789188
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4289.315438017915
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4509.65459224378
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4242.973454245383
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4292.5785260887915
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4290.018540543332
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4222.792420599177
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4218.556675575597
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4409.246173649706
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4174.122378753751
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4435.92088353245
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4111.770770008254
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4197.8915011996605
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4175.947033987199
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4169.857801413184
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4093.135998410793

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           4093.14
# Name: 63, dtype: object

# %% [markdown]
# ## Fitting an ARIMA Time Series Model

# %% [markdown]
# Using grid search, we have identified the set of parameters that produces the best fitting model to our time series data. We can proceed to analyze this particular model in more depth.
#
# We'll start by plugging the optimal parameter values into a new SARIMAX model.

# %%
#pick model with best AIC value, could try second best too


# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(zip_dict[20001],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# /Users/tmm/anaconda3/envs/learn-env/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8440      0.034     24.856      0.000       0.777       0.911
# ma.L1          0.7278      0.037     19.884      0.000       0.656       0.800
# ar.S.L12       0.1637      0.053      3.095      0.002       0.060       0.267
# ma.S.L12      -0.6853      0.037    -18.409      0.000      -0.758      -0.612
# sigma2      1.382e+06   9.27e+04     14.918      0.000     1.2e+06    1.56e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated

# %%
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here to ensure that residuals remain uncorrelated, normally distributed having zero mean. In the absence of these assumptions, we can not move forward and need further tweaking of the model.
#
# Let's check for these assumptions from diagnostics plots.
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?
#
# Should I conclude that the model has no correlations and provides a satisfactory fit to help forecast future values?

# %% [markdown]
# ## Validating the Model

# %% [markdown]
# To validate the model we compare predicted values to real values of the time series

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals.

pred = output.get_prediction(start=pd.to_datetime('2002-01-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = zip_dict[20001]['1998':].plot(label='observed')

#Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=.5)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts align with the true values as seen above,with overall increase trend. We shall also check for the accuracy of our forecasts using MSE (Mean Squared Error). This will provide us with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted = pred.predicted_mean
Price_truth = zip_dict[20001]['2000-01-01':]

# Compute the mean square error
mse = ((Price_forecasted - Price_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2002-01-01 00:00:00   NaN
# 2002-02-01 00:00:00   NaN
# 2002-03-01 00:00:00   NaN
# 2002-04-01 00:00:00   NaN
# 2002-05-01 00:00:00   NaN
# 2002-06-01 00:00:00   NaN
# 2002-07-01 00:00:00   NaN
# 2002-08-01 00:00:00   NaN
# 2002-09-01 00:00:00   NaN
# 2002-10-01 00:00:00   NaN
# 2002-11-01 00:00:00   NaN
# 2002-12-01 00:00:00   NaN
# 2003-01-01 00:00:00   NaN
# 2003-02-01 00:00:00   NaN
# 2003-03-01 00:00:00   NaN
# 2003-04-01 00:00:00   NaN
# 2003-05-01 00:00:00   NaN
# 2003-06-01 00:00:00   NaN
# 2003-07-01 00:00:00   NaN
# 2003-08-01 00:00:00   NaN
# 2003-09-01 00:00:00   NaN
# 2003-10-01 00:00:00   NaN
# 2003-11-01 00:00:00   NaN
# 2003-12-01 00:00:00   NaN
# 2004-01-01 00:00:00   NaN
# 2004-02-01 00:00:00   NaN
# 2004-03-01 00:00:00   NaN
# 2004-04-01 00:00:00   NaN
# 2004-05-01 00:00:00   NaN
# 2004-06-01 00:00:00   NaN
#                        ..
# 2015-12-01 00:00:00   NaN
# 2016-01-01 00:00:00   NaN
# 2016-02-01 00:00:00   NaN
# 2016-03-01 00:00:00   NaN
# 2016-04-01 00:00:00   NaN
# 2016-05-01 00:00:00   NaN
# 2016-06-01 00:00:00   NaN
# 2016-07-01 00:00:00   NaN
# 2016-08-01 00:00:00   NaN
# 2016-09-01 00:00:00   NaN
# 2016-10-01 00:00:00   NaN
# 2016-11-01 00:00:00   NaN
# 2016-12-01 00:00:00   NaN
# 2017-01-01 00:00:00   NaN
# 2017-02-01 00:00:00   NaN
# 2017-03-01 00:00:00   NaN
# 2017-04-01 00:00:00   NaN
# 2017-05-01 00:00:00   NaN
# 2017-06-01 00:00:00   NaN
# 2017-07-01 00:00:00   NaN
# 2017-08-01 00:00:00   NaN
# 2017-09-01 00:00:00   NaN
# 2017-10-01 00:00:00   NaN
# 2017-11-01 00:00:00   NaN
# 2017-12-01 00:00:00   NaN
# 2018-01-01 00:00:00   NaN
# 2018-02-01 00:00:00   NaN
# 2018-03-01 00:00:00   NaN
# 2018-04-01 00:00:00   NaN
# value                 NaN
# Length: 197, dtype: float64

# %%
#melted20001

# %% [markdown]
# # ARIMA Modeling

# %% [markdown]
# ## Parameter Selection for ARIMA Time Series Model

# %% [markdown]
# The first step towards fitting an ARIMA model is to find the values of `ARIMA(p,d,q)(P,D,Q)s` that produce the desired output. Selection of these parameters requires domain expertise and time.  We shall first generate small ranges of these parameters and use a "grid search" to iteratively explore different combinations of parameters. For each combination of parameters, we fit a new seasonal ARIMA model with the `SARIMAX()` function from the statsmodels module and assess its overall quality.
#
# `SARIMAX` detailed documentation can be viewed [here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
#
# Let's begin by generating example combination of parameters that we wish to use.
#
# 1. Define p,q and d parameters to take any value from 0/1 using `range()` function. (Note: We can try larger values which can make our model computationally expensive to run, you can try this as an additional experiment)
#
# 2. Generate combinations for `(p,d,q)` using `itertools.product`.
# 3. Similarly, generate seasonal combinations as `(p,d,q)s`. Use s = 12 (constant)
# 4. Print some example combinations for seasonal ARIMA

# %%
import itertools

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0,2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets (use 12 for frequency)
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]


    # Define the p, d and q parameters to take any value between 0 and 2, 0-4 would be highest to try
    #p = d = q = range(0,2)

    # Generate all different combinations of p, q and q triplets
    #pdq = list(itertools.product(p, d, q))

    # Generate all different combinations of seasonal p, q and q triplets (use 12 for frequency)
    #pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %% [markdown]
# ## AIC (Akaike information Criterion) as Regularization Measure

# %% [markdown]
# For evaluating the model, we shall use the AIC (Akaike Information Criterion) value, which is provided by ARIMA models fitted using `statsmodels` library. The Akaike information criterion (AIC) is an estimator of the relative quality of statistical models for a given set of data. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models. Thus, AIC provides a means for model selection.
#
# A model that fits the data very well while using lots of features will be assigned a larger AIC score than a model that uses fewer features to achieve the same goodness-of-fit. Therefore, we are interested in finding the model that yields the lowest AIC value. To achieve this, perform following tasks:
#
# 1. Initialize an empty list to store results
# 2. iterate through all the paramaters in pdq with parameters in seasonal pdq (nested loop ) to create a grid
# 3. Run `SARIMAX` from statsmodels for each iteration. Details can be found [HERE](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html). Set `enforce_stationarity` and `enforce_invertibility` to False.
# 4. Get the results in each iteration with `model.fit()` and store the AIC values.
# 5. Find the lowest AIC and select parameters for further analysis.
#
# NOTE:
# * Integrate exception handling with `continue`.
# * An overview of Akaike Information Criterion can be viewed [HERE](http://www.statisticshowto.com/akaikes-information-criterion/)

# %%
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20001,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7607.3094680875965
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7109.73777056729
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6153.409075272848
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5873.529158829102
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =6040.0946863308545
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5966.084009863183
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5655.5583561289695
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =5635.086083943744
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7387.051587441354
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7362.489921991718
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =5954.440077969369
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =8161.497568330564
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7044.541238177362
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =6990.752551082477
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5672.386217201743
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7423.211916866556
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5156.3268564888285
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4883.152775759111
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4864.5795254941895
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4617.951332367549
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4834.949666968064
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4813.248466085148
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4622.047079089364
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4606.417305547146
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4812.156746545834
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4546.146955910248
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4668.914426852758
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4341.343249667372
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4617.422036681702
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4534.484155039174
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4434.956582744468
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4377.037381464817
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5049.472038975923
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4909.093870003696
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4884.835366663662
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4675.471997860842
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4797.6759997248555
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4798.987498044611
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4625.889356555569
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4627.72657364459
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4807.687018009315
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4586.492976628051
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4854.154053847542
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4378.186661487233
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4612.7619345201565
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4588.483088985295
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4440.405152894004
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4665.544993010512
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4499.797818789188
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4289.315438017915
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4509.65459224378
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4242.973454245383
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4292.5785260887915
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4290.018540543332
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4222.792420599177
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4218.556675575597
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4409.246173649706
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4174.122378753751
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4435.92088353245
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4111.770770008254
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4197.8915011996605
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4175.947033987199
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4169.857801413184
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4093.135998410793

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           4093.14
# Name: 63, dtype: object

# %% [markdown]
# ## Fitting an ARIMA Time Series Model

# %% [markdown]
# Using grid search, we have identified the set of parameters that produces the best fitting model to our time series data. We can proceed to analyze this particular model in more depth.
#
# We'll start by plugging the optimal parameter values into a new SARIMAX model.

# %%
#pick model with best AIC value, could try second best too


# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(melted20001[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8787      0.029     29.974      0.000       0.821       0.936
# ma.L1          0.7006      0.039     17.984      0.000       0.624       0.777
# ar.S.L12       0.1611      0.058      2.765      0.006       0.047       0.275
# ma.S.L12      -0.6983      0.044    -15.978      0.000      -0.784      -0.613
# sigma2      1.153e+06   7.78e+04     14.823      0.000       1e+06    1.31e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated

# %%
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here to ensure that residuals remain uncorrelated, normally distributed having zero mean. In the absence of these assumptions, we can not move forward and need further tweaking of the model.
#
# Let's check for these assumptions from diagnostics plots.
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?
#
# Should I conclude that the model has no correlations and provides a satisfactory fit to help forecast future values?

# %% [markdown]
# ## Validating the Model

# %% [markdown]
# To validate the model we compare predicted values to real values of the time series

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals.
#start where training left off

pred = output.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf = pred.conf_int()

# %%
pred_conf
# Out:
#               lower value    upper value
# 2016-01-01  699861.672801  704071.296661
# 2016-02-01  704907.194237  709116.818097
# 2016-03-01  706610.994699  710820.618553
# 2016-04-01  707635.449198  711845.073026
# 2016-05-01  712949.278334  717158.902098
# 2016-06-01  715593.588008  719803.211564
# 2016-07-01  719601.037841  723810.661335
# 2016-08-01  720106.883876  724316.507339
# 2016-09-01  720180.217448  724389.840898
# 2016-10-01  713515.234790  717724.858233
# 2016-11-01  715908.708855  720118.332295
# 2016-12-01  719362.870411  723572.493849
# 2017-01-01  733966.882258  738176.505696
# 2017-02-01  739990.128082  751635.471635
# 2017-03-01  744416.445062  764775.431706
# 2017-04-01  747983.670269  777835.738367
# 2017-05-01  751201.754288  791014.878453
# 2017-06-01  753884.272417  803919.504508
# 2017-07-01  755287.905515  815663.022377
# 2017-08-01  755975.331624  826706.622049
# 2017-09-01  755632.227053  836663.335327
# 2017-10-01  754613.848301  845836.364705
# 2017-11-01  754061.943068  855330.444472
# 2017-12-01  755493.101999  866636.312333
# 2018-01-01  757979.580535  879586.295291

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20001['2014':].plot(label='observed')

#Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=.5)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts align with the true values as seen above,with overall increase trend. We shall also check for the accuracy of our forecasts using MSE (Mean Squared Error). This will provide us with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
pred.predicted_mean
# Out:
# 2016-01-01    701966.484731
# 2016-02-01    707012.006167
# 2016-03-01    708715.806626
# 2016-04-01    709740.261112
# 2016-05-01    715054.090216
# 2016-06-01    717698.399786
# 2016-07-01    721705.849588
# 2016-08-01    722211.695608
# 2016-09-01    722285.029173
# 2016-10-01    715620.046512
# 2016-11-01    718013.520575
# 2016-12-01    721467.682130
# 2017-01-01    736071.693977
# 2017-02-01    745812.799858
# 2017-03-01    754595.938384
# 2017-04-01    762909.704318
# 2017-05-01    771108.316371
# 2017-06-01    778901.888462
# 2017-07-01    785475.463946
# 2017-08-01    791340.976836
# 2017-09-01    796147.781190
# 2017-10-01    800225.106503
# 2017-11-01    804696.193770
# 2017-12-01    811064.707166
# 2018-01-01    818782.937913
# Freq: MS, dtype: float64

# %%
melted20001['2000-01-01':]
# Out:
#                value
# time
# 2000-01-01  139300.0
# 2000-02-01  140700.0
# 2000-03-01  141800.0
# 2000-04-01  142800.0
# 2000-05-01  143700.0
# 2000-06-01  144600.0
# 2000-07-01  145600.0
# 2000-08-01  146600.0
# 2000-09-01  147700.0
# 2000-10-01  148900.0
# 2000-11-01  150100.0
# 2000-12-01  151600.0
# 2001-01-01  153300.0
# 2001-02-01  155200.0
# 2001-03-01  156900.0
# 2001-04-01  158500.0
# 2001-05-01  160000.0
# 2001-06-01  161600.0
# 2001-07-01  163300.0
# 2001-08-01  165000.0
# 2001-09-01  166700.0
# 2001-10-01  168600.0
# 2001-11-01  170700.0
# 2001-12-01  173100.0
# 2002-01-01  175800.0
# 2002-02-01  178900.0
# 2002-03-01  182100.0
# 2002-04-01  185400.0
# 2002-05-01  188900.0
# 2002-06-01  192700.0
# ...              ...
# 2015-11-01  694800.0
# 2015-12-01  698500.0
# 2016-01-01  701900.0
# 2016-02-01  705500.0
# 2016-03-01  707900.0
# 2016-04-01  710800.0
# 2016-05-01  714300.0
# 2016-06-01  717900.0
# 2016-07-01  720000.0
# 2016-08-01  720800.0
# 2016-09-01  719400.0
# 2016-10-01  718200.0
# 2016-11-01  719600.0
# 2016-12-01  726300.0
# 2017-01-01  734500.0
# 2017-02-01  740000.0
# 2017-03-01  744600.0
# 2017-04-01  751800.0
# 2017-05-01  759100.0
# 2017-06-01  762800.0
# 2017-07-01  765000.0
# 2017-08-01  768800.0
# 2017-09-01  771200.0
# 2017-10-01  773300.0
# 2017-11-01  777600.0
# 2017-12-01  780500.0
# 2018-01-01  781600.0
# 2018-02-01  785500.0
# 2018-03-01  791400.0
# 2018-04-01  793300.0
#
# [220 rows x 1 columns]

# %%
Price_forecasted - Price_truth.value
# Out:
# 2016-01-01       66.484731
# 2016-02-01     1512.006167
# 2016-03-01      815.806626
# 2016-04-01    -1059.738888
# 2016-05-01      754.090216
# 2016-06-01     -201.600214
# 2016-07-01     1705.849588
# 2016-08-01     1411.695608
# 2016-09-01     2885.029173
# 2016-10-01    -2579.953488
# 2016-11-01    -1586.479425
# 2016-12-01    -4832.317870
# 2017-01-01     1571.693977
# 2017-02-01     5812.799858
# 2017-03-01     9995.938384
# 2017-04-01    11109.704318
# 2017-05-01    12008.316371
# 2017-06-01    16101.888462
# 2017-07-01    20475.463946
# 2017-08-01    22540.976836
# 2017-09-01    24947.781190
# 2017-10-01    26925.106503
# 2017-11-01    27096.193770
# 2017-12-01    30564.707166
# 2018-01-01    37182.937913
# 2018-02-01             NaN
# 2018-03-01             NaN
# 2018-04-01             NaN
# dtype: float64

# %%
# Get the Real and predicted values
Price_forecasted = pred.predicted_mean
Price_truth = melted20001['2016-01-01':]

# Compute the mean square error
mse = ((Price_forecasted - Price_truth.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 241567280.42

# %% [markdown]
# ## Dynamic Forecasting

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
melted20001.head()
# Out:
#               value
# time
# 1996-04-01  92000.0
# 1996-05-01  92600.0
# 1996-06-01  93200.0
# 1996-07-01  93900.0
# 1996-08-01  94600.0

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic = output.get_prediction(start=pd.to_datetime('2000-01-01'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20001.plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf.index,
                pred_dynamic_conf.iloc[:, 0],
                pred_dynamic_conf.iloc[:, 1], color='g', alpha=.3)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2000-01-01'), Price_forecasted.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Price_forecasted = pred_dynamic.predicted_mean
Price_truth = melted20001['2000-01-01':]

# Compute the mean square error
mse = ((Price_forecasted - Price_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 2000-01-01 00:00:00   NaN
# 2000-02-01 00:00:00   NaN
# 2000-03-01 00:00:00   NaN
# 2000-04-01 00:00:00   NaN
# 2000-05-01 00:00:00   NaN
# 2000-06-01 00:00:00   NaN
# 2000-07-01 00:00:00   NaN
# 2000-08-01 00:00:00   NaN
# 2000-09-01 00:00:00   NaN
# 2000-10-01 00:00:00   NaN
# 2000-11-01 00:00:00   NaN
# 2000-12-01 00:00:00   NaN
# 2001-01-01 00:00:00   NaN
# 2001-02-01 00:00:00   NaN
# 2001-03-01 00:00:00   NaN
# 2001-04-01 00:00:00   NaN
# 2001-05-01 00:00:00   NaN
# 2001-06-01 00:00:00   NaN
# 2001-07-01 00:00:00   NaN
# 2001-08-01 00:00:00   NaN
# 2001-09-01 00:00:00   NaN
# 2001-10-01 00:00:00   NaN
# 2001-11-01 00:00:00   NaN
# 2001-12-01 00:00:00   NaN
# 2002-01-01 00:00:00   NaN
# 2002-02-01 00:00:00   NaN
# 2002-03-01 00:00:00   NaN
# 2002-04-01 00:00:00   NaN
# 2002-05-01 00:00:00   NaN
# 2002-06-01 00:00:00   NaN
#                        ..
# 2015-12-01 00:00:00   NaN
# 2016-01-01 00:00:00   NaN
# 2016-02-01 00:00:00   NaN
# 2016-03-01 00:00:00   NaN
# 2016-04-01 00:00:00   NaN
# 2016-05-01 00:00:00   NaN
# 2016-06-01 00:00:00   NaN
# 2016-07-01 00:00:00   NaN
# 2016-08-01 00:00:00   NaN
# 2016-09-01 00:00:00   NaN
# 2016-10-01 00:00:00   NaN
# 2016-11-01 00:00:00   NaN
# 2016-12-01 00:00:00   NaN
# 2017-01-01 00:00:00   NaN
# 2017-02-01 00:00:00   NaN
# 2017-03-01 00:00:00   NaN
# 2017-04-01 00:00:00   NaN
# 2017-05-01 00:00:00   NaN
# 2017-06-01 00:00:00   NaN
# 2017-07-01 00:00:00   NaN
# 2017-08-01 00:00:00   NaN
# 2017-09-01 00:00:00   NaN
# 2017-10-01 00:00:00   NaN
# 2017-11-01 00:00:00   NaN
# 2017-12-01 00:00:00   NaN
# 2018-01-01 00:00:00   NaN
# 2018-02-01 00:00:00   NaN
# 2018-03-01 00:00:00   NaN
# 2018-04-01 00:00:00   NaN
# value                 NaN
# Length: 221, dtype: float64

# %%
# Get forecast 10 steps ahead in future
prediction = output.get_forecast(steps=10)

# Get confidence intervals of forecasts
pred_conf = prediction.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20001.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# # Interpreting Results
