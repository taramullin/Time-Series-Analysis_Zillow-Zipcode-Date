# %% [markdown]
# # Time Series Modeling Project
# * Student name: Tara Mullin
# * Student pace: Part time
# * Scheduled project review date/time: 10/21/19 04:00pm EST
# * Instructor name: Victor Geislinger
# * Blog post URL: TBD

# %% [markdown]
# ## Project Goal
#
# To forcast real estate prices of various zipcodes using data from Zillow using time-series analysis.

# %% [markdown]
# What are the top 5 zip codes to invest in?
#
# Ideas:
# * least volitial?
# * gained most value?
# * more affordable now, but adjacent to valuable zip?

# %% [markdown]
# # Preparing Data for Modeling & EDA

# %% [markdown]
# ## Step 1: Load the Data & Filter for Selected Zipcodes

# %%
import pandas as pd
zip_data = pd.read_csv("zillow_data.csv")
zip_data.head(15)
# Out:
#     RegionID  RegionName           City State              Metro  \
# 0      84654       60657        Chicago    IL            Chicago
# 1      90668       75070       McKinney    TX  Dallas-Fort Worth
# 2      91982       77494           Katy    TX            Houston
# 3      84616       60614        Chicago    IL            Chicago
# 4      93144       79936        El Paso    TX            El Paso
# 5      91733       77084        Houston    TX            Houston
# 6      61807       10467       New York    NY           New York
# 7      84640       60640        Chicago    IL            Chicago
# 8      91940       77449           Katy    TX            Houston
# 9      97564       94109  San Francisco    CA      San Francisco
# 10     62037       11226       New York    NY           New York
# 11     71831       32162   The Villages    FL       The Villages
# 12     62087       11375       New York    NY           New York
# 13     62045       11235       New York    NY           New York
# 14     74101       37013      Nashville    TN          Nashville
#
#        CountyName  SizeRank   1996-04   1996-05   1996-06   ...     2017-07  \
# 0            Cook         1  334200.0  335400.0  336500.0   ...     1005500
# 1          Collin         2  235700.0  236900.0  236700.0   ...      308000
# 2          Harris         3  210400.0  212200.0  212200.0   ...      321000
# 3            Cook         4  498100.0  500900.0  503100.0   ...     1289800
# 4         El Paso         5   77300.0   77300.0   77300.0   ...      119100
# 5          Harris         6   95000.0   95200.0   95400.0   ...      157900
# 6           Bronx         7  152900.0  152700.0  152600.0   ...      394400
# 7            Cook         8  216500.0  216700.0  216900.0   ...      798000
# 8          Harris         9   95400.0   95600.0   95800.0   ...      166800
# 9   San Francisco        10  766000.0  771100.0  776500.0   ...     3767700
# 10          Kings        11  162000.0  162300.0  162600.0   ...      860200
# 11         Sumter        12  101000.0  100700.0  100400.0   ...      249900
# 12         Queens        13  252400.0  251800.0  251400.0   ...     1022600
# 13          Kings        14  190500.0  191000.0  191500.0   ...      767300
# 14       Davidson        15  112400.0  112700.0  113000.0   ...      193000
#
#     2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0   1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1    310000   312500   314100   315000   316600   318100   319600   321100
# 2    320600   320200   320400   320800   321200   321200   323000   326900
# 3   1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4    119400   120000   120300   120300   120300   120300   120500   121000
# 5    158700   160200   161900   162800   162800   162800   162900   163500
# 6    400000   407300   411600   413200   414300   413900   411400   413200
# 7    787100   776100   774900   777900   777900   778500   780500   782800
# 8    167400   168400   169600   170900   172300   173300   174200   175400
# 9   3763900  3775000  3799700  3793900  3778700  3770800  3763100  3779800
# 10   851000   853900   870000   885100   887800   890500   901700   930700
# 11   250400   249900   248700   247500   247100   246800   247500   249800
# 12  1033700  1048600  1066400  1081200  1088800  1092700  1089500  1084000
# 13   777300   788800   793900   796000   799700   806600   810600   813400
# 14   194900   196600   198800   201300   203800   205900   207600   210000
#
#     2018-04
# 0   1030600
# 1    321800
# 2    329900
# 3   1307000
# 4    121500
# 5    164300
# 6    417900
# 7    782800
# 8    176200
# 9   3813500
# 10   963200
# 11   251800
# 12  1084600
# 13   816200
# 14   211900
#
# [15 rows x 272 columns]

# %%
dc_zips = zip_data.loc[zip_data['State'] == 'DC']
dc_zips.head()
# Out:
#      RegionID  RegionName        City State       Metro            CountyName  \
# 29      66126       20002  Washington    DC  Washington  District of Columbia
# 33      66133       20009  Washington    DC  Washington  District of Columbia
# 181     66135       20011  Washington    DC  Washington  District of Columbia
# 246     66142       20019  Washington    DC  Washington  District of Columbia
# 258     66125       20001  Washington    DC  Washington  District of Columbia
#
#      SizeRank   1996-04   1996-05   1996-06   ...     2017-07  2017-08  \
# 29         30   94300.0   94000.0   93700.0   ...      662800   668000
# 33         34  178800.0  179200.0  179600.0   ...     1020000  1027500
# 181       182  118900.0  118500.0  118200.0   ...      582200   586200
# 246       247   91300.0   91000.0   90600.0   ...      291100   296300
# 258       259   92000.0   92600.0   93200.0   ...      765000   768800
#
#      2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 29    672200   673100   674600   678200   680900   683000   687500   691300
# 33   1034300  1040500  1047400  1055400  1065900  1076400  1081000  1078200
# 181   591200   593200   591200   589500   590800   599100   611400   619100
# 246   302500   306700   308800   310800   313400   314100   311800   308600
# 258   771200   773300   777600   780500   781600   785500   791400   793300
#
# [5 rows x 272 columns]

# %%
dc_zips.describe()
# Out:
#            RegionID    RegionName     SizeRank        1996-04        1996-05  \
# count     18.000000     18.000000    18.000000      18.000000      18.000000
# mean   66137.444444  20014.500000  2675.000000  189216.666667  188611.111111
# std        8.204893      9.739247  2493.070915  113639.762356  112984.735507
# min    66125.000000  20001.000000    30.000000   85700.000000   85500.000000
# 25%    66132.250000  20008.250000   295.000000  106000.000000  105650.000000
# 50%    66137.000000  20013.500000  1887.500000  126500.000000  126250.000000
# 75%    66141.750000  20018.750000  5329.500000  260800.000000  258900.000000
# max    66155.000000  20037.000000  6888.000000  450100.000000  448200.000000
#
#              1996-06        1996-07        1996-08        1996-09  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   188011.111111  187438.888889  186900.000000  186494.444444
# std    112325.089591  111657.064995  111042.609734  110470.493650
# min     85400.000000   85200.000000   85000.000000   84800.000000
# 25%    105250.000000  104875.000000  104500.000000  104175.000000
# 50%    126000.000000  125800.000000  125750.000000  125900.000000
# 75%    256925.000000  254950.000000  252950.000000  251175.000000
# max    446300.000000  444500.000000  442900.000000  441600.000000
#
#              1996-10      ...            2017-07       2017-08       2017-09  \
# count      18.000000      ...       1.800000e+01  1.800000e+01  1.800000e+01
# mean   186222.222222      ...       7.796444e+05  7.829056e+05  7.852778e+05
# std    109997.794393      ...       3.443848e+05  3.440163e+05  3.421486e+05
# min     84600.000000      ...       2.881000e+05  2.934000e+05  2.978000e+05
# 25%    104025.000000      ...       5.462750e+05  5.479500e+05  5.492750e+05
# 50%    126250.000000      ...       7.489000e+05  7.552500e+05  7.610500e+05
# 75%    249475.000000      ...       9.769750e+05  9.817250e+05  9.836500e+05
# max    440700.000000      ...       1.501600e+06  1.508800e+06  1.509700e+06
#
#             2017-10       2017-11       2017-12       2018-01       2018-02  \
# count  1.800000e+01  1.800000e+01  1.800000e+01  1.800000e+01  1.800000e+01
# mean   7.862611e+05  7.881222e+05  7.904500e+05  7.936222e+05  7.988389e+05
# std    3.396671e+05  3.391489e+05  3.395134e+05  3.403082e+05  3.412926e+05
# min    3.015000e+05  3.037000e+05  3.040000e+05  3.046000e+05  3.068000e+05
# 25%    5.500000e+05  5.486750e+05  5.514000e+05  5.543500e+05  5.610000e+05
# 50%    7.648000e+05  7.684500e+05  7.711500e+05  7.725500e+05  7.766500e+05
# 75%    9.836250e+05  9.869000e+05  9.909750e+05  9.952000e+05  1.002325e+06
# max    1.506000e+06  1.509100e+06  1.514300e+06  1.519400e+06  1.527900e+06
#
#             2018-03       2018-04
# count  1.800000e+01  1.800000e+01
# mean   8.046000e+05  8.061667e+05
# std    3.427029e+05  3.431798e+05
# min    3.082000e+05  3.074000e+05
# 25%    5.682000e+05  5.703500e+05
# 50%    7.830500e+05  7.857500e+05
# 75%    1.011925e+06  1.015700e+06
# max    1.539600e+06  1.545900e+06
#
# [8 rows x 268 columns]

# %%
dc_zips.RegionName.unique()
# Out:
# array([20002, 20009, 20011, 20019, 20001, 20020, 20008, 20003, 20032,
#        20016, 20010, 20007, 20024, 20017, 20018, 20037, 20015, 20012])

# %% [markdown]
# ## Step 2: Reshape from Wide to Long Format

# %%
def melt_data(df):
    melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %%
df = dc_zips[dc_zips.RegionName == 20002]
df.head()
# Out:
#     RegionID  RegionName        City State       Metro            CountyName  \
# 29     66126       20002  Washington    DC  Washington  District of Columbia
#
#     SizeRank  1996-04  1996-05  1996-06   ...     2017-07  2017-08  2017-09  \
# 29        30  94300.0  94000.0  93700.0   ...      662800   668000   672200
#
#     2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 29   673100   674600   678200   680900   683000   687500   691300
#
# [1 rows x 272 columns]

# %%
melted = pd.melt(df, id_vars=['RegionID','RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='time')

# %%
melted.head()
# Out:
#    RegionID  RegionName        City State       Metro            CountyName  \
# 0     66126       20002  Washington    DC  Washington  District of Columbia
# 1     66126       20002  Washington    DC  Washington  District of Columbia
# 2     66126       20002  Washington    DC  Washington  District of Columbia
# 3     66126       20002  Washington    DC  Washington  District of Columbia
# 4     66126       20002  Washington    DC  Washington  District of Columbia
#
#    SizeRank     time    value
# 0        30  1996-04  94300.0
# 1        30  1996-05  94000.0
# 2        30  1996-06  93700.0
# 3        30  1996-07  93600.0
# 4        30  1996-08  93400.0

# %%
melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)

# %%
melted = melted.dropna(subset=['value'])

# %%
melted.head()
# Out:
#    RegionID  RegionName        City State       Metro            CountyName  \
# 0     66126       20002  Washington    DC  Washington  District of Columbia
# 1     66126       20002  Washington    DC  Washington  District of Columbia
# 2     66126       20002  Washington    DC  Washington  District of Columbia
# 3     66126       20002  Washington    DC  Washington  District of Columbia
# 4     66126       20002  Washington    DC  Washington  District of Columbia
#
# 2018-03-01  687500.0
# 2018-04-01  691300.0
#
# [265 rows x 1 columns]

# %% [markdown]
# Next Steps:
#
#     * group by ward?
#     * plot a zip code over time
#     * plot 2, 5, up to 12 together over time
#     * choose 5 to model to understand the projected outcome of these 5
#     * could model all zips, but not expected for the project

# %% [markdown]
# ## Step 3: EDA and Visualization

# %%
import matplotlib.pyplot as plt

# NOTE: if your visualizations are too cluttered to read, try calling 'plt.gcf().autofmt_xdate()'!

zip_dict[20002].plot(figsize = (15,5), subplots=False, legend=True)
zip_dict[20009].plot(figsize = (15,5), subplots=False, legend=True)
plt.show()

# %%
#plotting all DC zip codes (only 18 can plot all together)

plt.plot(zip_dict[20001], label='20001')
plt.plot(zip_dict[20002], label='20002')
plt.plot(zip_dict[20003], label='20003')
plt.plot(zip_dict[20007], label='20007')
plt.plot(zip_dict[20008], label='20008')
plt.plot(zip_dict[20009], label='20009')
plt.plot(zip_dict[20010], label='20010')
plt.plot(zip_dict[20011], label='20011')
plt.plot(zip_dict[20012], label='20012')
plt.plot(zip_dict[20015], label='20015')
plt.plot(zip_dict[20016], label='20016')
plt.plot(zip_dict[20017], label='20017')
plt.plot(zip_dict[20018], label='20018')
plt.plot(zip_dict[20019], label='20019')
plt.plot(zip_dict[20020], label='20020')
plt.plot(zip_dict[20024], label='20024')
plt.plot(zip_dict[20032], label='20032')
plt.plot(zip_dict[20037], label='20037')
plt.legend(loc='upper left')
plt.show()

# %%
# based on a visual analysis of all the zip codes

plt.plot(zip_dict[20001], label='20001')
plt.plot(zip_dict[20002], label='20002')
plt.plot(zip_dict[20003], label='20003')
plt.plot(zip_dict[20007], label='20007')
plt.plot(zip_dict[20008], label='20008')
plt.plot(zip_dict[20009], label='20009')
plt.plot(zip_dict[20010], label='20010')
plt.plot(zip_dict[20016], label='20016')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# I consider these zip codes to be promising based on two main factors:
#
# 1. Growth - they display growth and appear to be continuing on an upward trajectory
# 2. Low Volatility - they seem to be more stabel and less impacted by the 2008 recession compared to others

# %% [markdown]
# ### Creating Scaled Variables to Visualize % Return to Compare how much the price in each zip code has changed since 1996

# %% [markdown]
# Now that I have selected some zip codes that appear to be promising based on price, I wanted to view the zip codes based on % return so that I can compare how much the price in each zip code has changed since 1996. Scaling the zip codes in this way sets the price in 1996 as the baseline and allows us to visualize how much the price increases or decreases from that baseline with each passing year.

# %%
#scaling all zip codes to visualize how much the price has increased since 1996
#scaled: (current - first) / first = % rtn

zip_dict["20001_scaled"]=(zip_dict[20001]-zip_dict[20001].iloc[0,0])/zip_dict[20001].iloc[0,0]
zip_dict["20002_scaled"]=(zip_dict[20002]-zip_dict[20002].iloc[0,0])/zip_dict[20002].iloc[0,0]
zip_dict["20003_scaled"]=(zip_dict[20003]-zip_dict[20003].iloc[0,0])/zip_dict[20003].iloc[0,0]
zip_dict["20007_scaled"]=(zip_dict[20007]-zip_dict[20007].iloc[0,0])/zip_dict[20007].iloc[0,0]
zip_dict["20008_scaled"]=(zip_dict[20008]-zip_dict[20008].iloc[0,0])/zip_dict[20008].iloc[0,0]
zip_dict["20009_scaled"]=(zip_dict[20009]-zip_dict[20009].iloc[0,0])/zip_dict[20009].iloc[0,0]
zip_dict["20010_scaled"]=(zip_dict[20010]-zip_dict[20010].iloc[0,0])/zip_dict[20010].iloc[0,0]
zip_dict["20011_scaled"]=(zip_dict[20011]-zip_dict[20011].iloc[0,0])/zip_dict[20011].iloc[0,0]
zip_dict["20012_scaled"]=(zip_dict[20012]-zip_dict[20012].iloc[0,0])/zip_dict[20012].iloc[0,0]
zip_dict["20015_scaled"]=(zip_dict[20015]-zip_dict[20015].iloc[0,0])/zip_dict[20015].iloc[0,0]
zip_dict["20016_scaled"]=(zip_dict[20016]-zip_dict[20016].iloc[0,0])/zip_dict[20016].iloc[0,0]
zip_dict["20017_scaled"]=(zip_dict[20017]-zip_dict[20017].iloc[0,0])/zip_dict[20017].iloc[0,0]
zip_dict["20018_scaled"]=(zip_dict[20018]-zip_dict[20018].iloc[0,0])/zip_dict[20018].iloc[0,0]
zip_dict["20019_scaled"]=(zip_dict[20019]-zip_dict[20019].iloc[0,0])/zip_dict[20019].iloc[0,0]
zip_dict["20020_scaled"]=(zip_dict[20020]-zip_dict[20020].iloc[0,0])/zip_dict[20020].iloc[0,0]
zip_dict["20024_scaled"]=(zip_dict[20024]-zip_dict[20024].iloc[0,0])/zip_dict[20024].iloc[0,0]
zip_dict["20032_scaled"]=(zip_dict[20032]-zip_dict[20032].iloc[0,0])/zip_dict[20032].iloc[0,0]
zip_dict["20037_scaled"]=(zip_dict[20037]-zip_dict[20037].iloc[0,0])/zip_dict[20037].iloc[0,0]

# %%
#visualizing all the scaled variables to understand which have gained the most value

plt.plot(zip_dict["20001_scaled"], label='20001 scaled')
plt.plot(zip_dict["20002_scaled"], label='20002 scaled')
plt.plot(zip_dict["20003_scaled"], label='20003 scaled')
plt.plot(zip_dict["20007_scaled"], label='20007 scaled')
plt.plot(zip_dict["20008_scaled"], label='20008 scaled')
plt.plot(zip_dict["20009_scaled"], label='20009 scaled')
plt.plot(zip_dict["20010_scaled"], label='20010 scaled')
plt.plot(zip_dict["20011_scaled"], label='20011 scaled')
plt.plot(zip_dict["20012_scaled"], label='20012 scaled')
plt.plot(zip_dict["20015_scaled"], label='20015 scaled')
plt.plot(zip_dict["20016_scaled"], label='20016 scaled')
plt.plot(zip_dict["20017_scaled"], label='20017 scaled')
plt.plot(zip_dict["20018_scaled"], label='20018 scaled')
plt.plot(zip_dict["20019_scaled"], label='20019 scaled')
plt.plot(zip_dict["20020_scaled"], label='20020 scaled')
plt.plot(zip_dict["20024_scaled"], label='20024 scaled')
plt.plot(zip_dict["20037_scaled"], label='20037 scaled')
plt.legend(loc='upper left')
plt.show()

# %%
#The following zip codes have gained the most value since 1996:
plt.plot(zip_dict["20001_scaled"], label='20001 scaled')
plt.plot(zip_dict["20002_scaled"], label='20002 scaled')
plt.plot(zip_dict["20003_scaled"], label='20003 scaled')
plt.plot(zip_dict["20009_scaled"], label='20009 scaled')
plt.plot(zip_dict["20010_scaled"], label='20010 scaled')
plt.plot(zip_dict["20011_scaled"], label='20011 scaled')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Comparing the top zip our two visual analyses:
#
#     - Based on raw price value:
#         1. 20008
#         2. 20007
#         3. 20016
#         4. 20009
#         5. 20003
#         6. 20001
#         7. 20010
#         8. 20002
#
#     - Based on percent return
#         1. 20001
#         2. 20002
#         3. 20010
#         4. 20003
#         5. 20009
#         6. 20011
#
#     - Overlap between the two:
#         1. 20001
#         2. 20002
#         3. 20010
#         4. 20003
#         5. 20009

# %%
#Plotting our top 5 zip codes together

plt.plot(zip_dict[20001], label='20001')
plt.plot(zip_dict[20002], label='20002')
plt.plot(zip_dict[20010], label='20010')
plt.plot(zip_dict[20003], label='20003')
plt.plot(zip_dict[20009], label='20009')
plt.legend(loc='upper left')
plt.show()

# %%
plt.plot(zip_dict["20001_scaled"], label='20001_scaled')
plt.plot(zip_dict["20002_scaled"], label='20002_scaled')
plt.plot(zip_dict["20010_scaled"], label='20010_scaled')
plt.plot(zip_dict["20003_scaled"], label='20003_scaled')
plt.plot(zip_dict["20009_scaled"], label='20009_scaled')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# - Most Valuable Currently: 20009
# - Gained Most Value Since 1996: 20001, 20002
# - Most Stable (Least Impacted by 2008 recession & generally stable): 20003, 20002
# - Most Affordable Currently: 20002
#
# *Analyzing the zip codes based on the above factors, I find that **20002** is the most promising zip code as it has gained the second most value since 1996, has generally been less volatile and is currently the most affordable.*
#
# *Second best zip code appears to be **20003**, although the present average price is higher, and the last year of data suggests that price increase could be slowing down*
#
# ***20001** and **20010** have seen impressive growth, and currently are lower priced on average compared to 20003, however they also have experienced some volatility over the years

# %% [markdown]
# Most linear time series forecasting methods assume normal distribution of observations. Check with .hist() or .plot(kind='kde')

# %%
zip_dict[20001].plot(kind= 'kde', title='20001')
zip_dict[20002].plot(kind='kde', title='20002')
zip_dict[20010].plot(kind= 'kde', title='20010')
zip_dict[20003].plot(kind= 'kde', title='20003')
zip_dict[20009].plot(kind= 'kde', title='20009')

# %% [markdown]
# These aren't normally distributed, all are bimodal, which may impact the results of the model and its ability to forcast accurately

# %% [markdown]
# ## Step 4: Prepare Dataframes of 5 Selected Zipcodes to Model

# %%
zip20001 = zip_data.loc[zip_data['RegionName'] == 20001]
zip20002 = zip_data.loc[zip_data['RegionName'] == 20002]
zip20010 = zip_data.loc[zip_data['RegionName'] == 20010]
zip20003 = zip_data.loc[zip_data['RegionName'] == 20003]
zip20009 = zip_data.loc[zip_data['RegionName'] == 20009]

zip20001.head() #checking to see that it worked
# Out:
#      RegionID  RegionName        City State       Metro            CountyName  \
# 258     66125       20001  Washington    DC  Washington  District of Columbia
#
#      SizeRank  1996-04  1996-05  1996-06   ...     2017-07  2017-08  2017-09  \
# 258       259  92000.0  92600.0  93200.0   ...      765000   768800   771200
#
#      2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 258   773300   777600   780500   781600   785500   791400   793300
#
# [1 rows x 272 columns]

# %%
zip20002.head() #double checking
# Out:
#     RegionID  RegionName        City State       Metro            CountyName  \
# 29     66126       20002  Washington    DC  Washington  District of Columbia
#
#     SizeRank  1996-04  1996-05  1996-06   ...     2017-07  2017-08  2017-09  \
# 29        30  94300.0  94000.0  93700.0   ...      662800   668000   672200
#
#     2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 29   673100   674600   678200   680900   683000   687500   691300
#
# [1 rows x 272 columns]

# %%
#reshaping from wide to long format using melt_data method defined above

melted20001 = melt_data(zip20001)
melted20002 = melt_data(zip20002)
melted20010 = melt_data(zip20010)
melted20003 = melt_data(zip20003)
melted20009 = melt_data(zip20009)

melted20001.head() #checking to see that it worked
# Out:
#               value
# time
# 1996-04-01  92000.0
# 1996-05-01  92600.0
# 1996-06-01  93200.0
# 1996-07-01  93900.0
# 1996-08-01  94600.0

# %%
melted20009.head() #double checking
# Out:
#                value
# time
# 1996-04-01  178800.0
# 1996-05-01  179200.0
# 1996-06-01  179600.0
# 1996-07-01  180000.0
# 1996-08-01  180300.0

# %%
#checking to make sure there are no missing values
print(melted20001.isna().sum())
print(melted20002.isna().sum())
print(melted20010.isna().sum())
print(melted20003.isna().sum())
print(melted20009.isna().sum())
# Out:
# value    0
# dtype: int64
# value    0
# dtype: int64
# value    0
# dtype: int64
# value    0
# dtype: int64
# value    0
# dtype: int64

# %% [markdown]
# # ARIMA Modeling

# %% [markdown]
# ## Zipcode = 20001

# %% [markdown]
# ### Parameter Selection for ARIMA Time Series Model Using AIC (Akaike information Criterion)

# %% [markdown]
# The first step towards fitting an ARIMA model is to find the values of `ARIMA(p,d,q)(P,D,Q)s` that produce the desired output. Selection of these parameters requires domain expertise and time.  I first generated small ranges of these parameters and used a "grid search" to iteratively explore different combinations of parameters. For each combination of parameters, I fit a new seasonal ARIMA model with the `SARIMAX()` function from the statsmodels module and assess its overall quality.
#
# `SARIMAX` detailed documentation can be viewed [here](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html)
#
# To find the combination of parameters to use:
#
# 1. Define p,q and d parameters to take any value from 0/2 using `range()` function. (Note: We can try larger values which can make our model computationally expensive to run, you can try this as an additional experiment)
#
# 2. Generate combinations for `(p,d,q)` using `itertools.product`.
# 3. Generate seasonal combinations as `(p,d,q)s`. Use s = 12 (constant)

# %%
import itertools

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0,2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets (use 12 for frequency)
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %% [markdown]
# For evaluating the model, I used the AIC (Akaike Information Criterion) value, which is provided by ARIMA models fitted using `statsmodels` library. The Akaike information criterion (AIC) is an estimator of the relative quality of statistical models for a given set of data. Given a collection of models for the data, AIC estimates the quality of each model, relative to each of the other models. Thus, AIC provides a means for model selection.
#
# A model that fits the data very well while using lots of features will be assigned a larger AIC score than a model that uses fewer features to achieve the same goodness-of-fit. Therefore, we are interested in finding the model that yields the lowest AIC value. To achieve this, I performed the following:
#
# 1. Initialized an empty list to store results
# 2. Iterated through all the paramaters in pdq with parameters in seasonal pdq (nested loop) to create a grid
# 3. Run `SARIMAX` from statsmodels for each iteration. Details can be found [HERE](https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html). Set `enforce_stationarity` and `enforce_invertibility` to False.
# 4. Got the results in each iteration with `model.fit()` and store the AIC values.
# 5. Found the lowest AIC and select parameters for further analysis.
#
# * An overview of Akaike Information Criterion can be viewed [HERE](http://www.statisticshowto.com/akaikes-information-criterion/)

# %%
import warnings
warnings.filterwarnings('ignore')
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
plt.style.use('ggplot')

# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20001,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7607.3094680875965
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7109.73777056729
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6153.409075272848
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5873.529158829102
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =6040.0946863308545
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5966.084009863183
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5655.5583561289695
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =5635.086083943744
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7387.051587441354
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7362.489921991718
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =5954.440077969369
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =8161.497568330564
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7044.541238177362
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =6990.752551082477
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5672.386217201743
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7423.211916866556
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5156.3268564888285
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4883.152775759111
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4864.5795254941895
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4617.951332367549
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4834.949666968064
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4813.248466085148
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4622.047079089364
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4606.417305547146
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4812.156746545834
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4546.146955910248
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4668.914426852758
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4341.343249667372
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4617.422036681702
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4534.484155039174
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4434.956582744468
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4377.037381464817
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5049.472038975923
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4909.093870003696
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4884.835366663662
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4675.471997860842
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4797.6759997248555
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4798.987498044611
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4625.889356555569
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4627.72657364459
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4807.687018009315
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4586.492976628051
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4854.154053847542
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4378.186661487233
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4612.7619345201565
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4588.483088985295
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4440.405152894004
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4665.544993010512
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4499.797818789188
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4289.315438017915
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4509.65459224378
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4242.973454245383
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4292.5785260887915
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4290.018540543332
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4222.792420599177
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4218.556675575597
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4409.246173649706
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4174.122378753751
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4435.92088353245
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4111.770770008254
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4197.8915011996605
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4175.947033987199
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4169.857801413184
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4093.135998410793

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           4093.14
# Name: 63, dtype: object

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4175.947034
# 62  (1, 1, 1)  (1, 1, 0, 12)  4169.857801
# 63  (1, 1, 1)  (1, 1, 1, 12)  4093.135998

# %% [markdown]
# ### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %% [markdown]
# Using grid search, I identified the set of parameters that produces the best fitting model to my time series data. I next continued to examine this particular model in more depth.
#
# I started by plugging the optimal parameter values into a new SARIMAX model. This time only fitting the model with data up to 2016 so that I can test the model's ability to make predictions by comparing it to the data we have for 2016 to 2018.

# %%
# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20001_1 = sm.tsa.statespace.SARIMAX(melted20001[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20001_1 = ARIMA_MODEL20001_1.fit()

print(output20001_1.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8787      0.029     29.974      0.000       0.821       0.936
# ma.L1          0.7006      0.039     17.984      0.000       0.624       0.777
# ar.S.L12       0.1611      0.058      2.765      0.006       0.047       0.275
# ma.S.L12      -0.6983      0.044    -15.978      0.000      -0.784      -0.613
# sigma2      1.153e+06   7.78e+04     14.823      0.000       1e+06    1.31e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20001_1.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# ### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20001_1 = output20001_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20001_1 = pred20001_1.conf_int()

# %%
pred_conf20001_1
# Out:
#               lower value    upper value
# 2016-01-01  699861.672801  704071.296661
# 2016-02-01  704907.194237  709116.818097
# 2016-03-01  706610.994699  710820.618553
# 2016-04-01  707635.449198  711845.073026
# 2016-05-01  712949.278334  717158.902098
# 2016-06-01  715593.588008  719803.211564
# 2016-07-01  719601.037841  723810.661335
# 2016-08-01  720106.883876  724316.507339
# 2016-09-01  720180.217448  724389.840898
# 2016-10-01  713515.234790  717724.858233
# 2016-11-01  715908.708855  720118.332295
# 2016-12-01  719362.870411  723572.493849
# 2017-01-01  733966.882258  738176.505696
# 2017-02-01  739990.128082  751635.471635
# 2017-03-01  744416.445062  764775.431706
# 2017-04-01  747983.670269  777835.738367
# 2017-05-01  751201.754288  791014.878453
# 2017-06-01  753884.272417  803919.504508
# 2017-07-01  755287.905515  815663.022377
# 2017-08-01  755975.331624  826706.622049
# 2017-09-01  755632.227053  836663.335327
# 2017-10-01  754613.848301  845836.364705
# 2017-11-01  754061.943068  855330.444472
# 2017-12-01  755493.101999  866636.312333
# 2018-01-01  757979.580535  879586.295291

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20001['2014':].plot(label = 'Observed')

#Plot predicted values
pred20001_1.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20001_1.index,
                pred_conf20001_1.iloc[:, 0],
                pred_conf20001_1.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. However, we see the forecast diverging from the true values during 2017 and the confidence interval increases greatly. The forecast predicted a larger increase in price than was actually observed in reality.
#
#
# I also checked for the accuracy of the forecasts using MSE (Mean Squared Error). This provides with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted20001_1 = pred20001_1.predicted_mean
Price_truth20001_1 = melted20001['2016-01-01':]

# Compute the mean square error
mse20001_1 = ((Price_forecasted20001_1 - Price_truth20001_1.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20001_1, 2)))
# Out:
# The Mean Squared Error of our forecasts is 241567280.42

# %% [markdown]
# The MSE is very large. Suggesting that this model is unlikely to yeild accurate predictions.

# %% [markdown]
# Given the results, I decided to try the parameters that produced second and third smallest AIC values to see if I could reduce the MSE.

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Second Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4175.947034
# 62  (1, 1, 1)  (1, 1, 0, 12)  4169.857801
# 63  (1, 1, 1)  (1, 1, 1, 12)  4093.135998

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20001_2 = sm.tsa.statespace.SARIMAX(melted20001[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 0, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20001_2 = ARIMA_MODEL20001_2.fit()

print(output20001_2.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8402      0.032     26.235      0.000       0.777       0.903
# ma.L1          0.6971      0.043     16.157      0.000       0.613       0.782
# ar.S.L12      -0.1085      0.021     -5.108      0.000      -0.150      -0.067
# sigma2      1.765e+06   1.19e+05     14.882      0.000    1.53e+06       2e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20001_2.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20001_2 = output20001_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20001_2 = pred20001_2.conf_int()

# %%
pred_conf20001_2
# Out:
#               lower value    upper value
# 2016-01-01  699761.989617  704969.285165
# 2016-02-01  705538.588546  710745.884094
# 2016-03-01  705633.071481  710840.367030
# 2016-04-01  707375.436558  712582.732107
# 2016-05-01  712665.342654  717872.638203
# 2016-06-01  715401.915804  720609.211352
# 2016-07-01  719166.871907  724374.167455
# 2016-08-01  721086.360962  726293.656511
# 2016-09-01  720529.523677  725736.819226
# 2016-10-01  712277.564946  717484.860494
# 2016-11-01  714962.434723  720169.730271
# 2016-12-01  718519.324219  723726.619768
# 2017-01-01  733388.145422  738595.440971
# 2017-02-01  738144.331373  752345.790560
# 2017-03-01  740386.269292  764864.798378
# 2017-04-01  741926.503869  777337.810864
# 2017-05-01  743327.118265  789955.562857
# 2017-06-01  744363.897109  802263.456646
# 2017-07-01  743677.179552  812755.211025
# 2017-08-01  741819.842861  821890.150919
# 2017-09-01  738107.998288  828925.823885
# 2017-10-01  734160.415029  835446.062904
# 2017-11-01  732068.412927  843523.415916
# 2017-12-01  734439.212151  855757.440128
# 2018-01-01  738543.812814  871230.314766

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20001['2014':].plot(label = 'Observed')

#Plot predicted values
pred20001_2.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20001_2.index,
                pred_conf20001_2.iloc[:, 0],
                pred_conf20001_2.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# As with the first model using the parameters associated with the lowest AIC value,  forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. The forecast still diverges from the true values during 2017 and the confidence interval increases greatly, but the forcast is closer to the true values on this model than on the original. This forecast still predicted a larger increase in price than was actually observed in reality.
#
# Next, checking MSE

# %%
# Get the Real and predicted values
Price_forecasted20001_2 = pred20001_2.predicted_mean
Price_truth20001_2 = melted20001['2016-01-01':]

# Compute the mean square error
mse20001_2 = ((Price_forecasted20001_2 - Price_truth20001_2.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20001_2, 2)))
# Out:
# The Mean Squared Error of our forecasts is 75507830.57

# %% [markdown]
# The MSE is still very large, but it is less than the original model. 241,567,280.42 > 75,507,830.57

# %%
print(mse20001_1)
print(mse20001_2)
# Out:
# 241567280.41841742
# 75507830.56935608

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Third Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4175.947034
# 62  (1, 1, 1)  (1, 1, 0, 12)  4169.857801
# 63  (1, 1, 1)  (1, 1, 1, 12)  4093.135998

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20001_3 = sm.tsa.statespace.SARIMAX(melted20001[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 0, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20001_3 = ARIMA_MODEL20001_3.fit()

print(output20001_3.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9652      0.016     58.666      0.000       0.933       0.997
# ma.L1          0.6692      0.036     18.512      0.000       0.598       0.740
# ar.S.L12      -0.0466      0.166     -0.281      0.779      -0.372       0.279
# ma.S.L12      -0.1915      0.163     -1.175      0.240      -0.511       0.128
# sigma2      7.995e+05   4.42e+04     18.080      0.000    7.13e+05    8.86e+05
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are NOT < 0.05, ar.S.L12 and ma.S.L12 are > 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20001_3.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20001_3 = output20001_3.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20001_3 = pred20001_3.conf_int()

# %%
pred_conf20001_3
# Out:
#               lower value    upper value
# 2016-01-01  699237.088544  702742.086306
# 2016-02-01  703165.341664  706670.339426
# 2016-03-01  707402.027278  710907.025040
# 2016-04-01  707792.559240  711297.557002
# 2016-05-01  712512.966288  716017.964050
# 2016-06-01  715817.169769  719322.167530
# 2016-07-01  719855.716050  723360.713812
# 2016-08-01  718596.115515  722101.113277
# 2016-09-01  719469.537467  722974.535229
# 2016-10-01  715677.088641  719182.086403
# 2016-11-01  716602.271423  720107.269185
# 2016-12-01  720474.300848  723979.298610
# 2017-01-01  733704.683059  737209.680820
# 2017-02-01  739114.625018  748991.021694
# 2017-03-01  743684.224893  761446.069367
# 2017-04-01  747263.031087  774086.163280
# 2017-05-01  749882.500012  786721.192095
# 2017-06-01  751760.774294  799410.702821
# 2017-07-01  753377.967906  812513.883340
# 2017-08-01  754626.648846  825827.105274
# 2017-09-01  755764.457573  839529.169782
# 2017-10-01  756506.205019  853268.845631
# 2017-11-01  756350.965218  866488.959893
# 2017-12-01  754615.234673  878457.482434
# 2018-01-01  752093.045685  889561.858451

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20001['2014':].plot(label = 'Observed')

#Plot predicted values
pred20001_3.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20001_3.index,
                pred_conf20001_3.iloc[:, 0],
                pred_conf20001_3.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %%
# Get the Real and predicted values
Price_forecasted20001_3 = pred20001_3.predicted_mean
Price_truth20001_3 = melted20001['2016-01-01':]

# Compute the mean square error
mse20001_3 = ((Price_forecasted20001_3 - Price_truth20001_3.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20001_3, 2)))
# Out:
# The Mean Squared Error of our forecasts is 275861580.72

# %% [markdown]
# This model produced the largest MSE of the three, and some of the p-values were greater than 0.05. The model using the parameters producing the second smallest AIC value is the best.

# %%
print(mse20001_1)
print(mse20001_2)
print(mse20001_3)
# Out:
# 241567280.41841742
# 75507830.56935608
# 275861580.7202825

# %% [markdown]
# ### Dynamic Forecasting with Best Model

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
melted20001.head()
# Out:
#               value
# time
# 1996-04-01  92000.0
# 1996-05-01  92600.0
# 1996-06-01  93200.0
# 1996-07-01  93900.0
# 1996-08-01  94600.0

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic20001_2 = output20001_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True, end=pd.to_datetime('2019-01-01'))
pred_dynamic_conf20001_2 = pred_dynamic20001_2.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20001.plot(label='observed', figsize=(20, 15))
pred_dynamic20001_2.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf20001_2.index,
                pred_dynamic_conf20001_2.iloc[:, 0],
                pred_dynamic_conf20001_2.iloc[:, 1], color='g', alpha=.3)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2000-01-01'), Price_forecasted20001_2.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Dynamic_Price_forecasted20001_2 = pred_dynamic20001_2.predicted_mean
Price_truth = melted20001['2016-01-01':]

# Compute the mean square error
mseDynmaic20001_2 = ((Dynamic_Price_forecasted20001_2 - Price_truth.value) ** 2).mean()
print('The Mean Squared Error of our dynamic forecasts is {}'.format(round(mseDynmaic20001_2, 2)))
# Out:
# The Mean Squared Error of our dynamic forecasts is 3702228691.35

# %%
# Get forecast 10 steps ahead in future
dynamicprediction20001_2 = output20001_2.get_forecast(steps=20)

# Get confidence intervals of forecasts
pred_conf20001_2 = dynamicprediction20001_2.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20001['2014':].plot(label='observed', figsize=(20, 15))
dynamicprediction20001_2.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf20001_2.index,
                pred_conf20001_2.iloc[:, 0],
                pred_conf20001_2.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# ## Zipcode = 20002

# %%
# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20002,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7531.1335326957915
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7036.739136934168
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6066.323606751242
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5790.506213169497
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =5938.391499805374
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5854.791186836779
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5512.518265837505
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =7400.118682405668
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7311.4913999805485
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =6935.329483709436
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =6064.115002783867
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =8031.612156726984
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =6971.637710122979
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =6918.4015836352355
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5584.9784800830785
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7381.025192979194
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5048.97547948692
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4746.40329031513
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4667.306614773404
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4452.525585805202
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4656.62611940781
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4641.9405703331595
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4469.4927044749975
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4453.900781398226
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4704.910741046126
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4403.425164249247
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4486.1423154917375
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4191.4863090796325
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4514.862288267601
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4383.560446870125
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4261.889382902752
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4186.41101699105
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =4916.305622052991
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4648.445810607553
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4686.961443420225
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4479.173653183195
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4633.626941313795
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4635.524831441572
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4471.51703726415
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4472.774300255784
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4687.20111684366
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4462.775721509699
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4707.425234569566
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4220.2373461117895
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4496.973694963791
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4464.788721263196
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4267.060261972678
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4241.679296851588
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4337.040744231095
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4136.604346537939
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4340.1952754312515
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4100.6023678848205
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4142.356478444629
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4132.037989888486
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4079.042889176696
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4077.939184795223
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4273.7491706356905
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4048.352262874524
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4286.494322961049
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4001.21661403475
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4085.3211474328837
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4049.6741946071415
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4061.9247826878445
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =3981.758227946061

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           3981.76
# Name: 63, dtype: object

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4049.674195
# 62  (1, 1, 1)  (1, 1, 0, 12)  4061.924783
# 63  (1, 1, 1)  (1, 1, 1, 12)  3981.758228

# %% [markdown]
# ### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %% [markdown]
# Using grid search, I identified the set of parameters that produces the best fitting model to my time series data. I next continued to examine this particular model in more depth.
#
# I started by plugging the optimal parameter values into a new SARIMAX model. This time only fitting the model with data up to 2016 so that I can test the model's ability to make predictions by comparing it to the data we have for 2016 to 2018.

# %%
# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20002_1 = sm.tsa.statespace.SARIMAX(melted20002[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20002_1 = ARIMA_MODEL20002_1.fit()

print(output20002_1.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9074      0.028     32.152      0.000       0.852       0.963
# ma.L1          0.5241      0.039     13.328      0.000       0.447       0.601
# ar.S.L12       0.1766      0.061      2.912      0.004       0.058       0.295
# ma.S.L12      -0.8080      0.065    -12.521      0.000      -0.934      -0.682
# sigma2      6.299e+05    4.4e+04     14.304      0.000    5.44e+05    7.16e+05
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20002_1.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# ### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20002_1 = output20002_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20002_1 = pred20002_1.conf_int()

# %%
pred_conf20002_1
# Out:
#               lower value    upper value
# 2016-01-01  587360.720726  590472.037226
# 2016-02-01  585284.764541  588396.081026
# 2016-03-01  587644.410760  590755.727012
# 2016-04-01  592557.818053  595669.133669
# 2016-05-01  599415.690277  602527.002003
# 2016-06-01  602669.427589  605780.705052
# 2016-07-01  607975.249108  611086.521331
# 2016-08-01  608514.697276  611625.967877
# 2016-09-01  607729.458681  610840.728928
# 2016-10-01  608549.517968  611660.788125
# 2016-11-01  618104.430999  621215.701134
# 2016-12-01  626309.604757  629420.874887
# 2017-01-01  635422.739862  638534.009990
# 2017-02-01  640714.823663  648894.592233
# 2017-03-01  645955.877452  660154.775254
# 2017-04-01  651140.187425  671993.606324
# 2017-05-01  655757.023697  683700.096186
# 2017-06-01  659926.590704  695256.114875
# 2017-07-01  662920.260465  705832.590218
# 2017-08-01  664527.590016  715143.899836
# 2017-09-01  665818.539865  724202.651351
# 2017-10-01  668272.716974  734444.181559
# 2017-11-01  671145.352347  745089.328113
# 2017-12-01  673803.330759  755478.189307
# 2018-01-01  675853.257901  765667.563993

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20002['2014':].plot(label = 'Observed')

#Plot predicted values
pred20002_1.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20002_1.index,
                pred_conf20002_1.iloc[:, 0],
                pred_conf20002_1.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. However, we see the forecast diverging from the true values during 2017 and the confidence interval increases greatly. The forecast predicted a larger increase in price than was actually observed in reality.
#
#
# I also checked for the accuracy of the forecasts using MSE (Mean Squared Error). This provides with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted20002_1 = pred20002_1.predicted_mean
Price_truth20002_1 = melted20002['2016-01-01':]

# Compute the mean square error
mse20002_1 = ((Price_forecasted20002_1 - Price_truth20002_1.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20002_1, 2)))
# Out:
# The Mean Squared Error of our forecasts is 282920659.91

# %% [markdown]
# The MSE is very large. Suggesting that this model is unlikely to yeild accurate predictions.

# %% [markdown]
# Given the results, I decided to try the parameters that produced second and third smallest AIC values to see if I could reduce the MSE.

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Second Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4049.674195
# 62  (1, 1, 1)  (1, 1, 0, 12)  4061.924783
# 63  (1, 1, 1)  (1, 1, 1, 12)  3981.758228

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20002_2 = sm.tsa.statespace.SARIMAX(melted20002[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 0, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20002_2 = ARIMA_MODEL20002_2.fit()

print(output20002_2.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8353      0.041     20.444      0.000       0.755       0.915
# ma.L1          0.5238      0.053      9.910      0.000       0.420       0.627
# ar.S.L12      -0.1313      0.024     -5.379      0.000      -0.179      -0.083
# sigma2      1.086e+06   8.01e+04     13.561      0.000    9.29e+05    1.24e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20002_2.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20002_2 = output20002_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20002_2 = pred20002_2.conf_int()

# %%
pred_conf20002_2
# Out:
#               lower value    upper value
# 2016-01-01  587659.976813  591745.414743
# 2016-02-01  585665.309679  589750.747609
# 2016-03-01  587305.934954  591391.372884
# 2016-04-01  592270.218411  596355.656341
# 2016-05-01  599454.921867  603540.359797
# 2016-06-01  602511.892601  606597.330531
# 2016-07-01  606579.120742  610664.558672
# 2016-08-01  607719.482049  611804.919979
# 2016-09-01  608095.407222  612180.845153
# 2016-10-01  608518.556675  612603.994605
# 2016-11-01  616682.912974  620768.350905
# 2016-12-01  625222.502812  629307.940742
# 2017-01-01  633899.985081  637985.423011
# 2017-02-01  637375.859546  647844.108583
# 2017-03-01  641454.263987  659157.247115
# 2017-04-01  646348.660570  671702.844118
# 2017-05-01  650572.385813  683741.940540
# 2017-06-01  654484.639485  695478.915669
# 2017-07-01  656264.994356  704996.126053
# 2017-08-01  655331.763047  711650.990549
# 2017-09-01  654087.987343  717809.454766
# 2017-10-01  656328.437600  727245.131884
# 2017-11-01  660520.170105  738414.713063
# 2017-12-01  665221.805991  749873.775372
# 2018-01-01  667810.576193  760379.824351

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20002['2014':].plot(label = 'Observed')

#Plot predicted values
pred20002_2.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20002_2.index,
                pred_conf20002_2.iloc[:, 0],
                pred_conf20002_2.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# As with the first model using the parameters associated with the lowest AIC value,  forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. The forecast still diverges from the true values during 2017 and the confidence interval increases greatly, but the forcast is closer to the true values on this model than on the original. This forecast still predicted a larger increase in price than was actually observed in reality.
#
# Next, checking MSE

# %%
# Get the Real and predicted values
Price_forecasted20002_2 = pred20002_2.predicted_mean
Price_truth20002_2 = melted20002['2016-01-01':]

# Compute the mean square error
mse20002_2 = ((Price_forecasted20002_2 - Price_truth20002_2.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20002_2, 2)))
# Out:
# The Mean Squared Error of our forecasts is 169276590.24

# %% [markdown]
# The MSE is still very large, but it is less than the original model.

# %%
print(mse20002_1)
print(mse20002_2)
# Out:
# 282920659.91369975
# 169276590.24423534

# %% [markdown]
# ### Dynamic Forecasting with Best Model

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic20002_2 = output20002_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True, end=pd.to_datetime('2019-01-01'))
pred_dynamic_conf20002_2 = pred_dynamic20002_2.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20002.plot(label='observed', figsize=(20, 15))
pred_dynamic20002_2.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf20002_2.index,
                pred_dynamic_conf20002_2.iloc[:, 0],
                pred_dynamic_conf20002_2.iloc[:, 1], color='g', alpha=.3)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Dynamic_Price_forecasted20002_2 = pred_dynamic20002_2.predicted_mean
Price_truth = melted20002['2016-01-01':]

# Compute the mean square error
mseDynmaic20002_2 = ((Dynamic_Price_forecasted20001_2 - Price_truth.value) ** 2).mean()
print('The Mean Squared Error of our dynamic forecasts is {}'.format(round(mseDynmaic20002_2, 2)))
# Out:
# The Mean Squared Error of our dynamic forecasts is 25742759291.21

# %%
# Get forecast 20 steps ahead in future
dynamicprediction20002_2 = output20002_2.get_forecast(steps=20)

# Get confidence intervals of forecasts
pred_conf20002_2 = dynamicprediction20002_2.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20002['2014':].plot(label='observed', figsize=(20, 15))
dynamicprediction20002_2.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf20002_2.index,
                pred_conf20002_2.iloc[:, 0],
                pred_conf20002_2.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# ## Zipcode = 20010

# %%
# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20010,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7620.337677269272
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7120.843287742191
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6118.223254303043
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5839.28524225855
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =6013.811855775159
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5941.06509937987
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5626.059840832878
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =7425.558461667666
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7400.199792215721
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7020.032153664718
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =6125.7919698165515
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =8866.452908511263
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7056.976791609114
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =7003.102241810724
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5639.0605510601345
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7511.025148631796
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5133.004543370477
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4869.371151096271
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4859.1945060192065
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4612.9364976087545
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4828.535000819082
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4807.789022223111
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4610.884861741461
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4593.651379366343
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4779.737208879826
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4526.333397099295
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4665.668069601141
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4376.360538713268
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4592.012943536701
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4515.644243593127
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4426.352066591309
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4363.627424011227
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5034.195885962841
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4995.985350955134
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4879.528272278253
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4663.765697600605
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4787.506349729978
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4789.043685518078
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4615.511920262443
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4921.933058688661
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4691.7070057153
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4559.912539243005
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4739.0167729097575
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4361.985903039743
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4584.381822633561
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4561.735709792989
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4426.493220464583
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4386.096790284937
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4487.27916634519
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4267.189927422396
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4508.198628550131
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4252.839971646403
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4268.277423810472
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4268.784680167713
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4223.036832397185
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4223.530471158185
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4387.266645246538
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4114.367798693729
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4426.868645560055
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4108.398340795795
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4157.837990424776
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4114.790110396354
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4159.343145062382
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4125.49635768776

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic            4108.4
# Name: 59, dtype: object

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4114.790110
# 62  (1, 1, 1)  (1, 1, 0, 12)  4159.343145
# 63  (1, 1, 1)  (1, 1, 1, 12)  4125.496358

# %% [markdown]
# ### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %% [markdown]
# Using grid search, I identified the set of parameters that produces the best fitting model to my time series data. I next continued to examine this particular model in more depth.
#
# I started by plugging the optimal parameter values into a new SARIMAX model. This time only fitting the model with data up to 2016 so that I can test the model's ability to make predictions by comparing it to the data we have for 2016 to 2018.

# %%
# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20010_1 = sm.tsa.statespace.SARIMAX(melted20010[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20010_1 = ARIMA_MODEL20010_1.fit()

print(output20010_1.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8839      0.033     26.389      0.000       0.818       0.950
# ma.L1          0.3963      0.020     19.398      0.000       0.356       0.436
# ar.S.L12      -0.5240      0.058     -8.996      0.000      -0.638      -0.410
# ma.S.L12      -0.0512      0.038     -1.365      0.172      -0.125       0.022
# sigma2      1.798e+06   1.34e+05     13.412      0.000    1.54e+06    2.06e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values, except for ONE are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20010_1.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# ### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20010_1 = output20010_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20010_1 = pred20010_1.conf_int()

# %%
pred_conf20010_1
# Out:
#               lower value    upper value
# 2016-01-01  706166.735055  711423.025638
# 2016-02-01  704484.040666  709740.331248
# 2016-03-01  701232.645604  706488.936187
# 2016-04-01  701759.694588  707015.985171
# 2016-05-01  706058.743307  711315.033890
# 2016-06-01  703456.340647  708712.631230
# 2016-07-01  698766.304888  704022.595470
# 2016-08-01  698163.692572  703419.983155
# 2016-09-01  695620.367246  700876.657829
# 2016-10-01  694099.526762  699355.817345
# 2016-11-01  696608.013352  701864.303935
# 2016-12-01  703377.388412  708633.678994
# 2017-01-01  712019.673434  717275.964017
# 2017-02-01  715320.967488  728408.372486
# 2017-03-01  718475.574680  740676.842190
# 2017-04-01  720879.146277  752984.308497
# 2017-05-01  722801.508499  765295.699719
# 2017-06-01  724336.533726  777500.290761
# 2017-07-01  724881.129282  788851.645329
# 2017-08-01  724274.607403  799086.252392
# 2017-09-01  723736.039985  809348.562711
# 2017-10-01  724028.841088  820347.675226
# 2017-11-01  723873.714837  830764.944465
# 2017-12-01  723737.748078  841039.317100
# 2018-01-01  722222.815275  850645.520407

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20010['2014':].plot(label = 'Observed')

#Plot predicted values
pred20010_1.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20010_1.index,
                pred_conf20010_1.iloc[:, 0],
                pred_conf20010_1.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. However, we see the forecast diverging from the true values during 2017 and the confidence interval increases greatly. The forecast predicted a larger increase in price than was actually observed in reality.
#
#
# I also checked for the accuracy of the forecasts using MSE (Mean Squared Error). This provides with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted20010_1 = pred20010_1.predicted_mean
Price_truth20010_1 = melted20010['2016-01-01':]

# Compute the mean square error
mse20010_1 = ((Price_forecasted20010_1 - Price_truth20010_1.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20010_1, 2)))
# Out:
# The Mean Squared Error of our forecasts is 166465226.3

# %% [markdown]
# The MSE is very large. Suggesting that this model is unlikely to yeild accurate predictions.

# %% [markdown]
# Given the results, I decided to try the parameters that produced second and third smallest AIC values to see if I could reduce the MSE.

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Second Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4114.790110
# 62  (1, 1, 1)  (1, 1, 0, 12)  4159.343145
# 63  (1, 1, 1)  (1, 1, 1, 12)  4125.496358

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20010_2 = sm.tsa.statespace.SARIMAX(melted20010[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 0, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20010_2 = ARIMA_MODEL20010_2.fit()

print(output20010_2.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8207      0.036     22.958      0.000       0.751       0.891
# ma.L1          0.7095      0.038     18.812      0.000       0.636       0.783
# ar.S.L12      -0.0774      0.018     -4.370      0.000      -0.112      -0.043
# sigma2      1.798e+06    1.2e+05     14.998      0.000    1.56e+06    2.03e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20010_2.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20010_2 = output20010_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20010_2 = pred20010_2.conf_int()

# %%
pred_conf20010_2
# Out:
#               lower value    upper value
# 2016-01-01  706081.285924  711337.582786
# 2016-02-01  705163.866197  710420.163059
# 2016-03-01  700817.034710  706073.331573
# 2016-04-01  702736.207510  707992.504372
# 2016-05-01  708005.095716  713261.392578
# 2016-06-01  705046.537558  710302.834420
# 2016-07-01  699024.948030  704281.244893
# 2016-08-01  697810.272801  703066.569664
# 2016-09-01  696463.091825  701719.388688
# 2016-10-01  693854.422964  699110.719827
# 2016-11-01  696211.931638  701468.228500
# 2016-12-01  704099.802977  709356.099840
# 2017-01-01  710555.540991  715811.837853
# 2017-02-01  708995.313421  723295.621630
# 2017-03-01  707246.116050  731751.168268
# 2017-04-01  706301.872974  741535.628982
# 2017-05-01  703774.830694  749896.090112
# 2017-06-01  698724.091031  755674.681264
# 2017-07-01  693064.229537  760655.412730
# 2017-08-01  687351.126856  765316.968923
# 2017-09-01  681901.262955  769932.727449
# 2017-10-01  678841.281027  776608.390934
# 2017-11-01  678445.976955  785612.293191
# 2017-12-01  680198.608792  796430.630554
# 2018-01-01  679830.059137  806665.189656

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20010['2014':].plot(label = 'Observed')

#Plot predicted values
pred20010_2.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20010_2.index,
                pred_conf20010_2.iloc[:, 0],
                pred_conf20010_2.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# As with the first model using the parameters associated with the lowest AIC value,  forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. The forecast still diverges from the true values during 2017 and the confidence interval increases greatly, but the forcast is closer to the true values on this model than on the original. This forecast still predicted a larger increase in price than was actually observed in reality.
#
# Next, checking MSE

# %%
# Get the Real and predicted values
Price_forecasted20010_2 = pred20010_2.predicted_mean
Price_truth20010_2 = melted20010['2016-01-01':]

# Compute the mean square error
mse20010_2 = ((Price_forecasted20010_2 - Price_truth20010_2.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20010_2, 2)))
# Out:
# The Mean Squared Error of our forecasts is 140615590.8

# %% [markdown]
# The MSE is still very large, but it is less than the original model.

# %%
print(mse20010_1)
print(mse20010_2)
# Out:
# 166465226.303284
# 140615590.8009539

# %% [markdown]
# ### Dynamic Forecasting with Best Model

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic20010_2 = output20010_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True, end=pd.to_datetime('2019-01-01'))
pred_dynamic_conf20010_2 = pred_dynamic20010_2.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20010.plot(label='observed', figsize=(20, 15))
pred_dynamic20010_2.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf20010_2.index,
                pred_dynamic_conf20010_2.iloc[:, 0],
                pred_dynamic_conf20010_2.iloc[:, 1], color='g', alpha=.3)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Dynamic_Price_forecasted20010_2 = pred_dynamic20010_2.predicted_mean
Price_truth = melted20010['2016-01-01':]

# Compute the mean square error
mseDynmaic20010_2 = ((Dynamic_Price_forecasted20010_2 - Price_truth.value) ** 2).mean()
print('The Mean Squared Error of our dynamic forecasts is {}'.format(round(mseDynmaic20010_2, 2)))
# Out:
# The Mean Squared Error of our dynamic forecasts is 6638382223.31

# %%
# Get forecast 20 steps ahead in future
dynamicprediction20010_2 = output20010_2.get_forecast(steps=20)

# Get confidence intervals of forecasts
pred_conf20010_2 = dynamicprediction20010_2.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20010['2014':].plot(label='observed', figsize=(20, 15))
dynamicprediction20010_2.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf20010_2.index,
                pred_conf20010_2.iloc[:, 0],
                pred_conf20010_2.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# ## Zipcode = 20003

# %%
# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20003,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7704.829550534537
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7200.713912552092
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6102.446734667422
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5824.654182573477
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =5991.158644345835
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =5929.308838407154
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5638.616825371824
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =7456.612230758599
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7484.325856278001
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7099.896566637562
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =5907.758890037263
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =9356.06040349252
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7137.833299099717
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =7083.368091816728
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5627.4782776123675
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7252.371428887758
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5102.082927567964
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4829.317260460128
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4835.997515551604
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4581.655704173901
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4799.3817242039595
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4777.735360200653
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4591.094687211484
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4570.632549369033
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4871.50598004772
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4503.484166484408
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4656.874108570871
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4317.470536281403
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4583.966831785637
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4502.835227867761
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4418.058923483926
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4359.984368080145
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5003.349644269023
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4832.598926896993
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4855.997512337147
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =6092.456946990197
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4761.159630844733
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4834.039083807315
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4595.353989628469
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =4594.7929819284445
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4765.1052278232655
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4547.145296223557
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =4880.01133243817
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4361.784762243121
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4572.249840561339
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4549.14375377309
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4417.160808314052
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =4381.721006187674
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4424.580332493091
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4218.301894079432
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4443.963795055902
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4197.404741292716
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4218.468530080308
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4218.71139232906
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4148.260282992499
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4148.021212020689
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4344.432335487935
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4109.245162260291
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4381.617200644439
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4080.4929941785135
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4143.569447350725
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4111.088887460996
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4129.884924729743
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4083.354234995588

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic           4080.49
# Name: 59, dtype: object

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4111.088887
# 62  (1, 1, 1)  (1, 1, 0, 12)  4129.884925
# 63  (1, 1, 1)  (1, 1, 1, 12)  4083.354235

# %% [markdown]
# ### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %% [markdown]
# Using grid search, I identified the set of parameters that produces the best fitting model to my time series data. I next continued to examine this particular model in more depth.
#
# I started by plugging the optimal parameter values into a new SARIMAX model. This time only fitting the model with data up to 2016 so that I can test the model's ability to make predictions by comparing it to the data we have for 2016 to 2018.

# %%
# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20003_1 = sm.tsa.statespace.SARIMAX(melted20003[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20003_1 = ARIMA_MODEL20003_1.fit()

print(output20003_1.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9177      0.030     30.312      0.000       0.858       0.977
# ma.L1          0.3512      0.022     15.789      0.000       0.308       0.395
# ar.S.L12      -0.4840      0.066     -7.286      0.000      -0.614      -0.354
# ma.S.L12      -0.0410      0.033     -1.260      0.208      -0.105       0.023
# sigma2      1.347e+06   1.04e+05     12.898      0.000    1.14e+06    1.55e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values except for ONE are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20003_1.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# ### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20003_1 = output20003_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20003_1 = pred20003_1.conf_int()

# %%
pred_conf20003_1
# Out:
#               lower value    upper value
# 2016-01-01  741976.555897  746525.984635
# 2016-02-01  741365.200521  745914.629260
# 2016-03-01  740748.190690  745297.619428
# 2016-04-01  747623.448252  752172.876991
# 2016-05-01  756434.349325  760983.778064
# 2016-06-01  761190.492005  765739.920744
# 2016-07-01  762214.998445  766764.427184
# 2016-08-01  763107.940767  767657.369505
# 2016-09-01  762501.654814  767051.083553
# 2016-10-01  763379.925990  767929.354729
# 2016-11-01  768972.518031  773521.946770
# 2016-12-01  779287.955195  783837.383934
# 2017-01-01  790867.891168  795417.319907
# 2017-02-01  797346.744114  808627.115439
# 2017-03-01  802673.834601  821941.435833
# 2017-04-01  807474.044022  835594.760537
# 2017-05-01  812827.999599  850418.153454
# 2017-06-01  818737.015929  866238.039914
# 2017-07-01  822941.580117  880665.840158
# 2017-08-01  825460.399953  893621.920159
# 2017-09-01  826202.850113  904939.153544
# 2017-10-01  827361.871073  916750.149371
# 2017-11-01  829886.762206  929956.204154
# 2017-12-01  833404.245537  944145.645133
# 2018-01-01  835333.954203  957607.661429

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20003['2014':].plot(label = 'Observed')

#Plot predicted values
pred20003_1.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20003_1.index,
                pred_conf20003_1.iloc[:, 0],
                pred_conf20003_1.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. However, we see the forecast diverging from the true values during 2017 and the confidence interval increases greatly. The forecast predicted a larger increase in price than was actually observed in reality.
#
#
# I also checked for the accuracy of the forecasts using MSE (Mean Squared Error). This provides with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted20003_1 = pred20003_1.predicted_mean
Price_truth20003_1 = melted20003['2016-01-01':]

# Compute the mean square error
mse20003_1 = ((Price_forecasted20003_1 - Price_truth20003_1.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20003_1, 2)))
# Out:
# The Mean Squared Error of our forecasts is 1308327531.31

# %% [markdown]
# The MSE is very large. Suggesting that this model is unlikely to yeild accurate predictions.

# %% [markdown]
# Given the results, I decided to try the parameters that produced second and third smallest AIC values to see if I could reduce the MSE.

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Second Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4111.088887
# 62  (1, 1, 1)  (1, 1, 0, 12)  4129.884925
# 63  (1, 1, 1)  (1, 1, 1, 12)  4083.354235

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20003_2 = sm.tsa.statespace.SARIMAX(melted20003[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 0, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20003_2 = ARIMA_MODEL20003_2.fit()

print(output20003_2.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8779      0.039     22.604      0.000       0.802       0.954
# ma.L1          0.5850      0.050     11.805      0.000       0.488       0.682
# ar.S.L12      -0.0966      0.017     -5.843      0.000      -0.129      -0.064
# sigma2      1.347e+06   9.96e+04     13.524      0.000    1.15e+06    1.54e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20003_2.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20003_2 = output20003_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20003_2 = pred20003_2.conf_int()

# %%
pred_conf20003_2
# Out:
#               lower value    upper value
# 2016-01-01  742490.487564  747039.922306
# 2016-02-01  740677.993479  745227.428221
# 2016-03-01  739207.139575  743756.574318
# 2016-04-01  748280.029293  752829.464036
# 2016-05-01  757139.079856  761688.514599
# 2016-06-01  761897.331805  766446.766548
# 2016-07-01  761736.821031  766286.255773
# 2016-08-01  763597.172332  768146.607075
# 2016-09-01  761655.533860  766204.968603
# 2016-10-01  763874.302493  768423.737236
# 2016-11-01  769875.403985  774424.838728
# 2016-12-01  779859.565881  784409.000624
# 2017-01-01  789475.876074  794025.310817
# 2017-02-01  792948.343089  805041.763309
# 2017-03-01  797089.308710  817991.232179
# 2017-04-01  802073.572816  832548.970927
# 2017-05-01  806523.615024  847028.516754
# 2017-06-01  809614.001270  860399.395632
# 2017-07-01  810457.698833  871632.721710
# 2017-08-01  809471.305606  881044.745160
# 2017-09-01  807434.675811  889343.631507
# 2017-10-01  807340.692051  899471.032506
# 2017-11-01  810314.624676  912515.925031
# 2017-12-01  815587.700331  927684.317679
# 2018-01-01  818521.651611  941986.507848

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20003['2014':].plot(label = 'Observed')

#Plot predicted values
pred20003_2.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20003_2.index,
                pred_conf20003_2.iloc[:, 0],
                pred_conf20003_2.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# As with the first model using the parameters associated with the lowest AIC value,  forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. The forecast still diverges from the true values during 2017 and the confidence interval increases greatly, but the forcast is closer to the true values on this model than on the original. This forecast still predicted a larger increase in price than was actually observed in reality.
#
# Next, checking MSE

# %%
# Get the Real and predicted values
Price_forecasted20003_2 = pred20003_2.predicted_mean
Price_truth20003_2 = melted20003['2016-01-01':]

# Compute the mean square error
mse20003_2 = ((Price_forecasted20003_2 - Price_truth20003_2.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20003_2, 2)))
# Out:
# The Mean Squared Error of our forecasts is 759119014.32

# %% [markdown]
# The MSE is still very large, but it is less than the original model.

# %%
print(mse20003_1)
print(mse20003_2)
# Out:
# 1308327531.3130906
# 759119014.3229005

# %% [markdown]
# ### Dynamic Forecasting with Best Model

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic20003_2 = output20003_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True, end=pd.to_datetime('2019-01-01'))
pred_dynamic_conf20003_2 = pred_dynamic20003_2.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20003.plot(label='observed', figsize=(20, 15))
pred_dynamic20003_2.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf20003_2.index,
                pred_dynamic_conf20003_2.iloc[:, 0],
                pred_dynamic_conf20003_2.iloc[:, 1], color='g', alpha=.3)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Dynamic_Price_forecasted20003_2 = pred_dynamic20003_2.predicted_mean
Price_truth = melted20003['2016-01-01':]

# Compute the mean square error
mseDynmaic20003_2 = ((Dynamic_Price_forecasted20003_2 - Price_truth.value) ** 2).mean()
print('The Mean Squared Error of our dynamic forecasts is {}'.format(round(mseDynmaic20003_2, 2)))
# Out:
# The Mean Squared Error of our dynamic forecasts is 992951912.7

# %%
# Get forecast 20 steps ahead in future
dynamicprediction20003_2 = output20003_2.get_forecast(steps=20)

# Get confidence intervals of forecasts
pred_conf20003_2 = dynamicprediction20003_2.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20003['2014':].plot(label='observed', figsize=(20, 15))
dynamicprediction20003_2.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf20003_2.index,
                pred_conf20003_2.iloc[:, 0],
                pred_conf20003_2.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# ## Zipcode = 20009

# %%
# # Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
         try:
             mod = sm.tsa.statespace.SARIMAX(melted20009,
                                             order=comb,
                                             seasonal_order=combs,
                                             enforce_stationarity=False,
                                             enforce_invertibility=False)

             output = mod.fit()
             ans.append([comb, combs, output.aic])
             print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
         except:
             continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =7828.355924987523
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =7319.140512719291
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =6225.516156213202
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =5941.923010402188
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =6102.726739388336
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =6047.9015711037355
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =5740.291139822055
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =7675.436248778626
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =7607.251379104227
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =7217.4844437528845
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =6030.571678534039
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =6159.78762626762
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =7761.923954947961
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =7200.466029171637
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =5742.439326837699
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =7500.756685258741
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =5236.769038886683
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4967.6688779487395
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4950.368480003244
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4674.120950134937
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4924.543207471461
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4897.677872943308
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4667.779341462146
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4651.346431744275
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =5008.683783317731
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4772.089791585326
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4785.7464258830605
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4435.92361357297
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4822.022090751359
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4773.915113817713
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4548.054208369876
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4495.784146073354
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =5120.4067078704065
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =4885.0581264007415
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =4970.81721463686
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =4749.177613229263
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =4874.566798527153
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =4985.525284202544
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =4677.490942153147
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =5898.28023202096
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =4880.810759486207
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =4796.821913065603
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =5028.056676382232
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =4542.752643508868
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =4683.469258317404
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =4662.946369442046
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =4579.702065358404
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =5079.078204637837
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =4525.073959048262
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =4312.328138736326
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =4532.761751881044
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =4290.055298770069
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =4311.172222805924
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =4314.264995865221
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =4248.075155256478
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =4258.330295726284
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =4455.320593786317
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =4195.958351590507
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =4475.662176407762
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =4190.2260817704655
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =4235.874645073092
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =4197.290023517815
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =4233.66529219615
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =4182.190139047854

# %%
 # Find the parameters with minimal AIC value.
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           4182.19
# Name: 63, dtype: object

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4197.290024
# 62  (1, 1, 1)  (1, 1, 0, 12)  4233.665292
# 63  (1, 1, 1)  (1, 1, 1, 12)  4182.190139

# %% [markdown]
# ### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %% [markdown]
# Using grid search, I identified the set of parameters that produces the best fitting model to my time series data. I next continued to examine this particular model in more depth.
#
# I started by plugging the optimal parameter values into a new SARIMAX model. This time only fitting the model with data up to 2016 so that I can test the model's ability to make predictions by comparing it to the data we have for 2016 to 2018.

# %%
# plug the optimal parameter values into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20009_1 = sm.tsa.statespace.SARIMAX(melted20009[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 1, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20009_1 = ARIMA_MODEL20009_1.fit()

print(output20009_1.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9016      0.029     31.102      0.000       0.845       0.958
# ma.L1          0.3026      0.020     14.772      0.000       0.262       0.343
# ar.S.L12      -0.5302      0.067     -7.910      0.000      -0.662      -0.399
# ma.S.L12      -0.0215      0.030     -0.725      0.468      -0.080       0.037
# sigma2      2.347e+06    1.9e+05     12.338      0.000    1.97e+06    2.72e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values except for ONE are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20009_1.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# ### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20009_1 = output20009_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20009_1 = pred20009_1.conf_int()

# %%
pred_conf20009_1
# Out:
#              lower value   upper value
# 2016-01-01  9.255360e+05  9.315409e+05
# 2016-02-01  9.235215e+05  9.295263e+05
# 2016-03-01  9.211370e+05  9.271418e+05
# 2016-04-01  9.237696e+05  9.297745e+05
# 2016-05-01  9.274143e+05  9.334192e+05
# 2016-06-01  9.308736e+05  9.368784e+05
# 2016-07-01  9.348008e+05  9.408057e+05
# 2016-08-01  9.358076e+05  9.418125e+05
# 2016-09-01  9.410425e+05  9.470473e+05
# 2016-10-01  9.464303e+05  9.524352e+05
# 2016-11-01  9.601380e+05  9.661428e+05
# 2016-12-01  9.699656e+05  9.759705e+05
# 2017-01-01  9.768391e+05  9.828439e+05
# 2017-02-01  9.814981e+05  9.960321e+05
# 2017-03-01  9.854137e+05  1.009939e+06
# 2017-04-01  9.886350e+05  1.024110e+06
# 2017-05-01  9.924980e+05  1.039564e+06
# 2017-06-01  9.955003e+05  1.054578e+06
# 2017-07-01  9.971616e+05  1.068516e+06
# 2017-08-01  9.990366e+05  1.082813e+06
# 2017-09-01  1.001316e+06  1.097571e+06
# 2017-10-01  1.003012e+06  1.111736e+06
# 2017-11-01  1.003407e+06  1.124538e+06
# 2017-12-01  1.001755e+06  1.135190e+06
# 2018-01-01  9.993839e+05  1.146089e+06

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20009['2014':].plot(label = 'Observed')

#Plot predicted values
pred20009_1.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20009_1.index,
                pred_conf20009_1.iloc[:, 0],
                pred_conf20009_1.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# The forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. However, we see the forecast diverging from the true values during 2017 and the confidence interval increases greatly. The forecast predicted a larger increase in price than was actually observed in reality.
#
#
# I also checked for the accuracy of the forecasts using MSE (Mean Squared Error). This provides with the average error of our forecasts. For each predicted value, we compute its distance to the true value and square the result. The results need to be squared so that positive/negative differences do not cancel each other out when we compute the overall mean.

# %%
# Get the Real and predicted values
Price_forecasted20009_1 = pred20009_1.predicted_mean
Price_truth20009_1 = melted20009['2016-01-01':]

# Compute the mean square error
mse20009_1 = ((Price_forecasted20009_1 - Price_truth20009_1.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20009_1, 2)))
# Out:
# The Mean Squared Error of our forecasts is 71215260.0

# %% [markdown]
# The MSE is very large. Suggesting that this model is unlikely to yeild accurate predictions.

# %% [markdown]
# Given the results, I decided to try the parameters that produced second and third smallest AIC values to see if I could reduce the MSE.

# %% [markdown]
# ### Repeat Steps Above Using Parameters Producing Second Smallest AIC Value

# %%
ans_df.tail(3) #the top 3
# Out:
#           pdq           pdqs          aic
# 61  (1, 1, 1)  (1, 0, 1, 12)  4197.290024
# 62  (1, 1, 1)  (1, 1, 0, 12)  4233.665292
# 63  (1, 1, 1)  (1, 1, 1, 12)  4182.190139

# %% [markdown]
# #### Fitting ARIMA Time Series Model Using Parameters with Minimal AIC Value

# %%
# plug in the parameter values leading to second lowest AIC value into a new SARIMAX model.
# Fit the model and print results
ARIMA_MODEL20009_2 = sm.tsa.statespace.SARIMAX(melted20009[:'2016'],
                                 order=(1, 1, 1),
                                 seasonal_order=(1, 1, 0, 12),
                                 enforce_stationarity=False,
                                 enforce_invertibility=False)
output20009_2 = ARIMA_MODEL20009_2.fit()

print(output20009_2.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9108      0.023     40.291      0.000       0.866       0.955
# ma.L1          0.1097      0.014      8.067      0.000       0.083       0.136
# ar.S.L12      -0.5457      0.054    -10.024      0.000      -0.652      -0.439
# sigma2      2.347e+06   1.62e+05     14.451      0.000    2.03e+06    2.66e+06
# ==============================================================================

# %% [markdown]
# Check p-values on coefficients
#
# * all of the p-values are < 0.05
#
# Then run model diagnostics to ensure that none of the assumptions made by the model have been violated:

# %%
output20009_2.plot_diagnostics(figsize=(15, 18))
plt.show()

# %% [markdown]
# The purpose here is to ensure that residuals remain uncorrelated, normally distributed having zero mean.
#
# Checking for these assumptions from diagnostics plots:
#
# * In the top right plot, the red KDE line does not follow closely with the N(0,1) line (where N(0,1)) is the standard notation for a normal distribution with mean 0 and standard deviation of 1). Residuals are not normally distributed?
#
# * The qq-plot on the bottom left shows that the ordered distribution of residuals (blue dots) don't fully follow the linear trend of the samples taken from a standard normal distribution with N(0, 1). Residuals are not normally distributed?
#
# * The residuals over time (top left plot) don't really look like white noise - some kind of trend I didn't account for?
#
# * Autocorrelation (i.e. correlogram) plot on the bottom right, shows that the time series residuals have low correlation with lagged versions of itself?

# %% [markdown]
# #### Validating the Model

# %% [markdown]
# To validate the model I compared predicted values to real values of the time series

# %%
# Get predictions starting from 2016-01-01 (where the training left off) and calculate confidence intervals.

pred20009_2 = output20009_2.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=False, end=pd.to_datetime('2018-01-01'))
pred_conf20009_2 = pred20009_2.conf_int()

# %%
pred_conf20009_2
# Out:
#              lower value   upper value
# 2016-01-01  9.259064e+05  9.319113e+05
# 2016-02-01  9.236332e+05  9.296381e+05
# 2016-03-01  9.211562e+05  9.271610e+05
# 2016-04-01  9.232958e+05  9.293006e+05
# 2016-05-01  9.273060e+05  9.333109e+05
# 2016-06-01  9.308494e+05  9.368543e+05
# 2016-07-01  9.346875e+05  9.406924e+05
# 2016-08-01  9.359565e+05  9.419614e+05
# 2016-09-01  9.406790e+05  9.466839e+05
# 2016-10-01  9.461713e+05  9.521762e+05
# 2016-11-01  9.592740e+05  9.652789e+05
# 2016-12-01  9.700268e+05  9.760317e+05
# 2017-01-01  9.771715e+05  9.831763e+05
# 2017-02-01  9.826975e+05  9.962350e+05
# 2017-03-01  9.876247e+05  1.009919e+06
# 2017-04-01  9.919402e+05  1.023827e+06
# 2017-05-01  9.969238e+05  1.038984e+06
# 2017-06-01  1.001032e+06  1.053667e+06
# 2017-07-01  1.003788e+06  1.067267e+06
# 2017-08-01  1.006767e+06  1.081260e+06
# 2017-09-01  1.010149e+06  1.095749e+06
# 2017-10-01  1.012911e+06  1.109652e+06
# 2017-11-01  1.014306e+06  1.122174e+06
# 2017-12-01  1.013563e+06  1.132507e+06
# 2018-01-01  1.012166e+06  1.143228e+06

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

#Plot observed values
ax = melted20009['2014':].plot(label = 'Observed')

#Plot predicted values
pred20009_2.predicted_mean.plot(ax=ax, label='One-step ahead forecast', alpha=.9)

#Plot the range for confidence intervals
ax.fill_between(pred_conf20009_2.index,
                pred_conf20009_2.iloc[:, 0],
                pred_conf20009_2.iloc[:, 1], color='g', alpha=.20)

#Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Price')
plt.legend()

plt.show()

# %% [markdown]
# As with the first model using the parameters associated with the lowest AIC value,  forecasts aligns with the true values from 2016 to 2017, with a tight confidence interval. The forecast still diverges from the true values during 2017 and the confidence interval increases greatly, but the forcast is closer to the true values on this model than on the original. This forecast still predicted a larger increase in price than was actually observed in reality.
#
# Next, checking MSE

# %%
# Get the Real and predicted values
Price_forecasted20009_2 = pred20009_2.predicted_mean
Price_truth20009_2 = melted20009['2016-01-01':]

# Compute the mean square error
mse20009_2 = ((Price_forecasted20009_2 - Price_truth20009_2.value) ** 2).mean() #one was a series and one was a df
print('The Mean Squared Error of our forecasts is {}'.format(round(mse20009_2, 2)))
# Out:
# The Mean Squared Error of our forecasts is 110748141.3

# %% [markdown]
# In this case, the MSE is larger than the original model.

# %%
print(mse20009_1)
print(mse20009_2)
# Out:
# 71215259.99971166
# 110748141.30387843

# %% [markdown]
# ### Dynamic Forecasting with Best Model

# %% [markdown]
# Used to gain deeper insight into the model's predictive power. Uses information from the time series up to a certain point, after that forecasts are generated using values from prvious forecasted time points

# %%
# Get dynamic predictions with confidence intervals as above.
pred_dynamic20009_1 = output20009_1.get_prediction(start=pd.to_datetime('2016-01-01'), dynamic=True, full_results=True, end=pd.to_datetime('2019-01-01'))
pred_dynamic_conf20009_1 = pred_dynamic20009_1.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = melted20009.plot(label='observed', figsize=(20, 15))
pred_dynamic20009_1.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf20009_1.index,
                pred_dynamic_conf20009_1.iloc[:, 0],
                pred_dynamic_conf20009_1.iloc[:, 1], color='g', alpha=.3)

ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %%
# Extract the predicted and true values of our time series
Dynamic_Price_forecasted20009_1 = pred_dynamic20009_1.predicted_mean
Price_truth = melted20009['2016-01-01':]

# Compute the mean square error
mseDynmaic20009_1 = ((Dynamic_Price_forecasted20009_1 - Price_truth.value) ** 2).mean()
print('The Mean Squared Error of our dynamic forecasts is {}'.format(round(mseDynmaic20009_1, 2)))
# Out:
# The Mean Squared Error of our dynamic forecasts is 3218428292.51

# %%
# Get forecast 20 steps ahead in future
dynamicprediction20009_1 = output20009_1.get_forecast(steps=20)

# Get confidence intervals of forecasts
pred_conf20009_1 = dynamicprediction20009_1.conf_int()

# %%
# Plot future predictions with confidence intervals

ax = melted20009['2014':].plot(label='observed', figsize=(20, 15))
dynamicprediction20009_1.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf20009_1.index,
                pred_conf20009_1.iloc[:, 0],
                pred_conf20009_1.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Price')

plt.legend()
plt.show()

# %% [markdown]
# # Interpreting Results

# %% [markdown]
# All of the models have a lot of issues.
#   * The underlying data for the prices of each zipcode are non-normally distributed, which may be part of the problem.
#   * The residuals of each model are not normally distributed
#   * All MSE values are very, very high
#   * All forecasting is off after about 1 year
#
# Perhaps the SARIMAX model is not complex enough to model this data.
#
# The best model (based on lowest MSE value) for each zipcode besides 20009 came from using the parameters that yeilded the second lowest AIC value. The MSE for the 20009 model was the lowest when the parameters from the lowest AIC value were used.
#
# The MSE values are ranked from least to greatest below:

# %%
print('#1 The MSE for 20009 model is {}'.format(round(mse20009_1,2)))
print('#2 The MSE for 20001 model is {}'.format(round(mse20001_2,2)))
print('#3 The MSE for 20010 model is {}'.format(round(mse20010_2,2)))
print('#4 The MSE for 20002 model is {}'.format(round(mse20002_2,2)))
print('#5 The MSE for 20003 model is {}'.format(round(mse20003_2,2)))
# Out:
# #1 The MSE for 20009 model is 71215260.0
# #2 The MSE for 20001 model is 75507830.57
# #3 The MSE for 20010 model is 140615590.8
# #4 The MSE for 20002 model is 169276590.24
# #5 The MSE for 20003 model is 759119014.32

# %%
print('#1 The MSE of 20003 dynamic forecasts is {}'.format(round(mseDynmaic20003_2, 2)))
print('#2 The MSE of 20009 dynamic forecasts is {}'.format(round(mseDynmaic20009_1, 2)))
print('#3 The MSE of 20001 dynamic forecasts is {}'.format(round(mseDynmaic20001_2, 2)))
print('#4 The MSE of 20010 dynamic forecasts is {}'.format(round(mseDynmaic20010_2, 2)))
print('#5 The MSE of 20002 dynamic forecasts is {}'.format(round(mseDynmaic20002_2, 2)))
# Out:
# #1 The MSE of 20003 dynamic forecasts is 992951912.7
# #2 The MSE of 20009 dynamic forecasts is 3218428292.51
# #3 The MSE of 20001 dynamic forecasts is 3702228691.35
# #4 The MSE of 20010 dynamic forecasts is 6638382223.31
# #5 The MSE of 20002 dynamic forecasts is 25742759291.21

# %% [markdown]
# ## Recommendations & Future Directions

# %% [markdown]
# Given that the models performed so poorly, my recommendations are based on historical data.
#
# * Purchase a home in DC in zipcode 20002, it has experienced the second largest increase in price since 1996 (increased 6.25 fold) and is currently priced the lowest of the top 5 zipcodes. It has also been less volatile than other zipcodes historically. This zipcode had an average price of about 700,000 in 2018
#
# * Also consider 20003 if you are willing to spend a bit more now. This zipcode is the least volatile of the top 5 - it was the least impacted by the 2008 recession. This zipcode had an average price of about 820,000 in 2018

# %% [markdown]
# **Limitations & Future Work:**

# %% [markdown]
# * SARIMAX may not be the best model for this data
# * I likely didn't use the correct combination of parameters
# * Therefore, models have limited utility and accuracy
#
# * In the future, I'd like to research more complex models that would better suite this data
# * Investigate how to make the underlying data more complex
# * Reduce MSE and confidence intervals of predictions
# * Once I have a better model, I'd like to look into which month of the year is best to purchase a house (i.e. historically, which month of the year has the lowest sales prices)
